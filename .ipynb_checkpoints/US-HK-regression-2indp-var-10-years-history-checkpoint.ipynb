# %%
import pandas as pd
import numpy as np
import datetime as dt
import statsmodels.api as sm
#
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed

import tools
import importlib
importlib.reload(tools)
# Out:
# <module 'tools' from '/home/keithyamkf/jupyter-notebook/slack-trading/tools.py'>

# %% [markdown]
# ### Download data from AWS S3

# %%
s3_bucket = 'slack-trading'
local_path = '../data'
tools.download_data_from_s3(s3_bucket, local_path)

# %% [markdown]
# ### CPU Count

# %%
cpu_count()
# Out:
# 4

# %% [markdown]
# ### Begin

# %%
# dataset = pd.read_csv('../data/all_stock_close.csv')
dataset = pd.read_csv('../data/us_hk_clean_10yr_stock_close.csv')
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset.set_index('Date', drop=True, inplace=True)
dataset.head(3)
# Out:
#               0001.HK    0002.HK   0003.HK   0004.HK    0005.HK    0006.HK  \
# Date
# 2010-12-28  56.334431  41.966953  5.800245  7.799201  49.283875  26.950289
# 2010-12-29  57.905922  42.365368  5.895123  8.097270  49.750565  27.142986
# 2010-12-30  57.620216  42.199368  5.888801  8.229015  49.812798  27.170521
#
#             0007.HK   0008.HK    0010.HK    0011.HK  ...        VFC  \
# Date                                                 ...
# 2010-12-28     0.71  1.890068  40.080761  82.240196  ...  16.199192
# 2010-12-29     0.72  1.935749  40.827366  83.661453  ...  16.249552
# 2010-12-30     0.76  1.952879  41.063133  83.726082  ...  16.201061
#
#                  VRNT        WDC        WFC        WMT          ^DJI  \
# Date
# 2010-12-28  31.690001  26.569702  23.259796  41.967972  11575.540039
# 2010-12-29  31.540001  26.420523  23.125603  42.233482  11585.379883
# 2010-12-30  31.500000  26.420523  22.976505  42.225681  11569.709961
#
#                   ^GSPC        ^IXIC   ^TNX       ^VIX
# Date
# 2010-12-28  1258.510010  2662.879883  3.481  17.520000
# 2010-12-29  1259.780029  2666.929932  3.341  17.280001
# 2010-12-30  1257.880005  2662.979980  3.369  17.520000
#
# [3 rows x 812 columns]

# %%
train_start = '2011-01-01'
train_end = '2011-12-31'
dataset = dataset[train_start:train_end]

# %%
prevday_returns = np.log(dataset.shift(1)/dataset.shift(2))
today_returns = np.log(dataset/dataset.shift(1))
#
stocks_prev = prevday_returns.columns.to_list()
stocks_today_draft = today_returns.columns.to_list()
stocks_today = [s for s in stocks_today_draft if '.HK' in s]
#
new_col = ['{}.prev'.format(c) for c in stocks_prev]
prevday_returns.columns = new_col
#
comb_df = pd.concat([prevday_returns, today_returns[stocks_today]], axis=1)
comb_df.shape
# Out:
# (245, 1525)

# %% [markdown]
# ### Fina the NaN in comb_df

# %%
comb_df.dropna(axis=0, how='any', inplace=True)

# %%
comb_df.tail(3)
# Out:
#             0001.HK.prev  0002.HK.prev  0003.HK.prev  0004.HK.prev  \
# Date
# 2011-12-28      0.012451      0.002274      0.007808      0.011281
# 2011-12-29      0.004829     -0.007599     -0.001112     -0.025573
# 2011-12-30     -0.009142     -0.000763     -0.006697     -0.004321
#
#             0005.HK.prev  0006.HK.prev  0007.HK.prev  0008.HK.prev  \
# Date
# 2011-12-28      0.014316      0.003512     -0.029853      0.054347
# 2011-12-29     -0.010084      0.006987     -0.015268     -0.003839
# 2011-12-30     -0.013606     -0.008741      0.000000      0.041437
#
#             0010.HK.prev  0011.HK.prev  ...   3900.HK   3918.HK   3933.HK  \
# Date                                    ...
# 2011-12-28      0.042260      0.007547  ... -0.048374  0.005141 -0.002238
# 2011-12-29     -0.005764     -0.004845  ... -0.014685  0.005115 -0.009009
# 2011-12-30      0.009206     -0.003243  ... -0.002963  0.000000  0.011247
#
#              3968.HK   3988.HK   3989.HK   3993.HK   3998.HK   3999.HK  \
# Date
# 2011-12-28 -0.017483 -0.020762 -0.057175  0.000000 -0.013129 -0.007435
# 2011-12-29 -0.008854  0.000000 -0.060644 -0.020495 -0.013304 -0.030305
# 2011-12-30 -0.002545  0.000000  0.459543 -0.017911 -0.018019  0.015268
#
#              6823.HK
# Date
# 2011-12-28  0.000000
# 2011-12-29  0.000000
# 2011-12-30  0.013247
#
# [3 rows x 1525 columns]

# %%
comb_df.head(3)
# Out:
#             0001.HK.prev  0002.HK.prev  0003.HK.prev  0004.HK.prev  \
# Date
# 2011-01-05      0.012648     -0.005488      0.002165      0.001615
# 2011-01-06      0.010938      0.004706     -0.001083     -0.011347
# 2011-01-07      0.021523      0.004684     -0.014168      0.004068
#
#             0005.HK.prev  0006.HK.prev  0007.HK.prev  0008.HK.prev  \
# Date
# 2011-01-05      0.003118      0.001009     -0.027029      0.008607
# 2011-01-06      0.023994      0.001009     -0.013793     -0.014388
# 2011-01-07      0.005456     -0.002018      0.013793      0.014388
#
#             0010.HK.prev  0011.HK.prev  ...   3900.HK   3918.HK   3933.HK  \
# Date                                    ...
# 2011-01-05      0.000955     -0.001539  ...  0.006369  0.000000  0.002567
# 2011-01-06      0.004764      0.017564  ...  0.015748  0.056834 -0.033907
# 2011-01-07      0.006632     -0.000757  ...  0.000000  0.000000  0.000000
#
#              3968.HK   3988.HK   3989.HK   3993.HK   3998.HK   3999.HK  \
# Date
# 2011-01-05  0.002462 -0.007203 -0.028982  0.010612  0.040191  0.000000
# 2011-01-06  0.000000  0.002407  0.000000 -0.017302 -0.021440 -0.006473
# 2011-01-07  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              6823.HK
# Date
# 2011-01-05 -0.008772
# 2011-01-06  0.008268
# 2011-01-07  0.063791
#
# [3 rows x 1525 columns]

# %%
prevday_returns = comb_df[new_col]
today_returns = comb_df[stocks_today]

# %%
print('{} {}'.format(len(new_col), len(stocks_today)))
# Out:
# 812 713

# %% [markdown]
# ### Load the regression result to identify the 1st independent variable

# %%
result_df = pd.read_csv('../data/us_hk_10yr_regression_pair.csv', index_col=0)
sorted_df = result_df.sort_values(by='RSquared', ascending=False)
sorted_df.head(10)
# Out:
#                   Prev    Today    Params    TValues  RSquared
# 351929    ['MFC.prev']  0945.HK  0.690853  18.223915  0.579488
# 351970  ['^GSPC.prev']  0945.HK  1.089096  13.407334  0.427222
# 351960    ['TWM.prev']  0945.HK -0.389780  13.076561  0.415043
# 351946    ['SKF.prev']  0945.HK -0.398197  13.007148  0.412462
# 541744  ['^GSPC.prev']  2888.HK  0.867833  12.970602  0.411099
# 4051    ['^GSPC.prev']  0005.HK  0.799084  12.880493  0.407727
# 351969   ['^DJI.prev']  0945.HK  1.178357  12.787499  0.404232
# 541743   ['^DJI.prev']  2888.HK  0.951731  12.665678  0.399630
# 4050     ['^DJI.prev']  0005.HK  0.874710  12.540778  0.394885
# 351941    ['OMC.prev']  0945.HK  0.833398  12.538312  0.394791

# %%
sorted_df[sorted_df['RSquared'].isna()]
# Out:
#                     Prev    Today  Params  TValues  RSquared
# 324400  ['0001.HK.prev']  0865.HK     0.0      NaN       NaN
# 324401  ['0002.HK.prev']  0865.HK     0.0      NaN       NaN
# 324402  ['0003.HK.prev']  0865.HK     0.0      NaN       NaN
# 324403  ['0004.HK.prev']  0865.HK     0.0      NaN       NaN
# 324404  ['0005.HK.prev']  0865.HK     0.0      NaN       NaN
# ...                  ...      ...     ...      ...       ...
# 416849     ['^DJI.prev']  1159.HK     0.0      NaN       NaN
# 416850    ['^GSPC.prev']  1159.HK     0.0      NaN       NaN
# 416851    ['^IXIC.prev']  1159.HK     0.0      NaN       NaN
# 416852     ['^TNX.prev']  1159.HK     0.0      NaN       NaN
# 416853     ['^VIX.prev']  1159.HK     0.0      NaN       NaN
#
# [2433 rows x 5 columns]

# %%
sorted_df.fillna(0, inplace=True)

# %% [markdown]
# ##### Find the row grouped by 'Today' with max RSquared within each group

# %%
best_prev_sofar_df = sorted_df.loc[sorted_df.groupby('Today')['RSquared'].idxmax()]
best_prev_sofar_df
# Out:
#                     Prev    Today    Params    TValues  RSquared
# 807       ['^GSPC.prev']  0001.HK  0.669469   9.250636  0.262036
# 1212    ['0868.HK.prev']  0002.HK -0.069499   4.558865  0.079391
# 2427        ['WMT.prev']  0003.HK  0.284930   4.248075  0.069664
# 3230        ['TWM.prev']  0004.HK -0.307499   9.521562  0.273353
# 4051      ['^GSPC.prev']  0005.HK  0.799084  12.880493  0.407727
# ...                  ...      ...       ...        ...       ...
# 574295  ['0195.HK.prev']  3989.HK  0.385728   3.373660  0.045097
# 575769      ['MOS.prev']  3993.HK  0.594305  10.713548  0.322615
# 576534       ['BA.prev']  3998.HK  0.625689   6.049255  0.131824
# 577345       ['BA.prev']  3999.HK  0.552494   6.751476  0.159055
# 577564  ['0237.HK.prev']  6823.HK  4.017138   8.961810  0.249955
#
# [713 rows x 5 columns]

# %%
best_prev_sofar_df[best_prev_sofar_df['Today']=='0005.HK']
# Out:
#                 Prev    Today    Params    TValues  RSquared
# 4051  ['^GSPC.prev']  0005.HK  0.799084  12.880493  0.407727

# %% [markdown]
# ### Regression

# %%
def get_linear_regression(pair, prevday_returns, today_returns):
    catstocks = pair['prev']
    column = pair['today']
    X = prevday_returns[catstocks].copy()
    X = sm.add_constant(X)
    y = today_returns[column]
    model = sm.OLS(y, X).fit()
    data = {
        'Prev' : catstocks,
        'Today' : column,
        'Params' : model.params.iloc[1],
        'TValues' : abs(model.tvalues.iloc[1]),
        'RSquared' : model.rsquared
    }
    # print(data)
    return data

# %% [markdown]
# ### Generate pair list

# %%
catstocks = new_col
pair_list = []
for column in today_returns.columns:
    best_prev_str = best_prev_sofar_df.loc[best_prev_sofar_df['Today']==column, 'Prev'].values[0]
    best_prev_list = best_prev_str.replace('\'','').strip('][').split(', ') # convert list representation to list
    for catstock in catstocks:
        if (column not in catstock) and (catstock not in best_prev_list):
            data = {
                'prev' : best_prev_list + [catstock],
                'today' : column
            }
            pair_list.append(data)
#

# %% [markdown]
# ### NON-Parallel processing

# %%
# %%time
results = [get_linear_regression(pair, prevday_returns, today_returns) for pair in pair_list]
result_df = pd.DataFrame(results)
result_df
# Out:
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# {'Prev': ['^GSPC.prev', '0002.HK.prev'], 'Today': '0001.HK', 'Params': 0.6755726717838497, 'TValues': 9.309749923232356, 'RSquared': 0.2655995379593332}
# {'Prev': ['^GSPC.prev', '0003.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687371270205974, 'TValues': 9.231553769191734, 'RSquared': 0.26380103040427416}
# {'Prev': ['^GSPC.prev', '0004.HK.prev'], 'Today': '0001.HK', 'Params': 0.67766755395786, 'TValues': 9.26382309371264, 'RSquared': 0.26398348398407856}
# {'Prev': ['^GSPC.prev', '0005.HK.prev'], 'Today': '0001.HK', 'Params': 0.6787652313160226, 'TValues': 9.346757442669846, 'RSquared': 0.2671897516092817}
# {'Prev': ['^GSPC.prev', '0006.HK.prev'], 'Today': '0001.HK', 'Params': 0.6706428073474366, 'TValues': 9.163081639609231, 'RSquared': 0.2620794690073506}
# {'Prev': ['^GSPC.prev', '0007.HK.prev'], 'Today': '0001.HK', 'Params': 0.6674900582449519, 'TValues': 9.212240637398315, 'RSquared': 0.26413709423895315}
# {'Prev': ['^GSPC.prev', '0008.HK.prev'], 'Today': '0001.HK', 'Params': 0.6737983278762684, 'TValues': 9.287729043479043, 'RSquared': 0.2646181818912424}
# {'Prev': ['^GSPC.prev', '0010.HK.prev'], 'Today': '0001.HK', 'Params': 0.6754065846823163, 'TValues': 9.296405800395469, 'RSquared': 0.26481168938709676}
# {'Prev': ['^GSPC.prev', '0011.HK.prev'], 'Today': '0001.HK', 'Params': 0.6807173611143076, 'TValues': 9.345026783535431, 'RSquared': 0.2668153426527582}
# {'Prev': ['^GSPC.prev', '0012.HK.prev'], 'Today': '0001.HK', 'Params': 0.6795167709855648, 'TValues': 9.300404043195234, 'RSquared': 0.2651021651459773}
# {'Prev': ['^GSPC.prev', '0014.HK.prev'], 'Today': '0001.HK', 'Params': 0.6685385292437483, 'TValues': 9.143280156192867, 'RSquared': 0.2620667193193593}
# {'Prev': ['^GSPC.prev', '0015.HK.prev'], 'Today': '0001.HK', 'Params': 0.6650171871361248, 'TValues': 9.176319970437326, 'RSquared': 0.26550265598690326}
# {'Prev': ['^GSPC.prev', '0016.HK.prev'], 'Today': '0001.HK', 'Params': 0.683122687959036, 'TValues': 9.310983373248002, 'RSquared': 0.26582462842771637}
# {'Prev': ['^GSPC.prev', '0017.HK.prev'], 'Today': '0001.HK', 'Params': 0.6773982055870764, 'TValues': 9.313542166320016, 'RSquared': 0.2655034122086244}
# {'Prev': ['^GSPC.prev', '0018.HK.prev'], 'Today': '0001.HK', 'Params': 0.6723934685573294, 'TValues': 9.24925080440724, 'RSquared': 0.2628686737088105}
# {'Prev': ['^GSPC.prev', '0019.HK.prev'], 'Today': '0001.HK', 'Params': 0.6704451159781869, 'TValues': 9.25244050854101, 'RSquared': 0.26351844899840304}
# {'Prev': ['^GSPC.prev', '0020.HK.prev'], 'Today': '0001.HK', 'Params': 0.6740559849091496, 'TValues': 9.325170687002661, 'RSquared': 0.2682939042216823}
# {'Prev': ['^GSPC.prev', '0023.HK.prev'], 'Today': '0001.HK', 'Params': 0.6717296181970958, 'TValues': 9.209464228723899, 'RSquared': 0.26228686266921364}
# {'Prev': ['^GSPC.prev', '0025.HK.prev'], 'Today': '0001.HK', 'Params': 0.6773213454158065, 'TValues': 9.19158443929684, 'RSquared': 0.2630971636731282}
# {'Prev': ['^GSPC.prev', '0026.HK.prev'], 'Today': '0001.HK', 'Params': 0.6658537233876077, 'TValues': 9.222285069158861, 'RSquared': 0.26930636575388167}
# {'Prev': ['^GSPC.prev', '0028.HK.prev'], 'Today': '0001.HK', 'Params': 0.6647025867035468, 'TValues': 9.116098170097564, 'RSquared': 0.26310903319010914}
# {'Prev': ['^GSPC.prev', '0031.HK.prev'], 'Today': '0001.HK', 'Params': 0.6773543777231534, 'TValues': 9.097089951009801, 'RSquared': 0.26269594772921034}
# {'Prev': ['^GSPC.prev', '0034.HK.prev'], 'Today': '0001.HK', 'Params': 0.6650557314453688, 'TValues': 9.134639720912197, 'RSquared': 0.2632327787157924}
# {'Prev': ['^GSPC.prev', '0035.HK.prev'], 'Today': '0001.HK', 'Params': 0.681106262038888, 'TValues': 9.385101845018431, 'RSquared': 0.2691280335397104}
# {'Prev': ['^GSPC.prev', '0038.HK.prev'], 'Today': '0001.HK', 'Params': 0.6830028059887214, 'TValues': 9.210565150219328, 'RSquared': 0.2642356888131129}
# {'Prev': ['^GSPC.prev', '0040.HK.prev'], 'Today': '0001.HK', 'Params': 0.6698068284961975, 'TValues': 9.233695609314994, 'RSquared': 0.26213797519453597}
# {'Prev': ['^GSPC.prev', '0041.HK.prev'], 'Today': '0001.HK', 'Params': 0.6915317004054156, 'TValues': 9.621895199935631, 'RSquared': 0.28433873904875095}
# {'Prev': ['^GSPC.prev', '0043.HK.prev'], 'Today': '0001.HK', 'Params': 0.6710131442967561, 'TValues': 9.227890302676114, 'RSquared': 0.2622798169696722}
# {'Prev': ['^GSPC.prev', '0045.HK.prev'], 'Today': '0001.HK', 'Params': 0.6670611434057041, 'TValues': 9.190706345266063, 'RSquared': 0.2631247670258625}
# {'Prev': ['^GSPC.prev', '0046.HK.prev'], 'Today': '0001.HK', 'Params': 0.6732194195868413, 'TValues': 9.221028242677578, 'RSquared': 0.26261089944552896}
# {'Prev': ['^GSPC.prev', '0047.HK.prev'], 'Today': '0001.HK', 'Params': 0.6715324698667515, 'TValues': 9.293019786460473, 'RSquared': 0.26761777004034937}
# {'Prev': ['^GSPC.prev', '0050.HK.prev'], 'Today': '0001.HK', 'Params': 0.6971003155456754, 'TValues': 9.64408268522352, 'RSquared': 0.28251258723718653}
# {'Prev': ['^GSPC.prev', '0051.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691747349428578, 'TValues': 9.213840808963377, 'RSquared': 0.2620533151199441}
# {'Prev': ['^GSPC.prev', '0052.HK.prev'], 'Today': '0001.HK', 'Params': 0.6702140057072781, 'TValues': 9.225392758523379, 'RSquared': 0.26212481338094185}
# {'Prev': ['^GSPC.prev', '0053.HK.prev'], 'Today': '0001.HK', 'Params': 0.6660163749466894, 'TValues': 9.089561670397908, 'RSquared': 0.26236347101150925}
# {'Prev': ['^GSPC.prev', '0056.HK.prev'], 'Today': '0001.HK', 'Params': 0.6686038042725048, 'TValues': 9.157327782522328, 'RSquared': 0.2620682221934657}
# {'Prev': ['^GSPC.prev', '0057.HK.prev'], 'Today': '0001.HK', 'Params': 0.6738222021673761, 'TValues': 9.236707949378683, 'RSquared': 0.2628848659169031}
# {'Prev': ['^GSPC.prev', '0062.HK.prev'], 'Today': '0001.HK', 'Params': 0.6927488493730023, 'TValues': 9.557708730392648, 'RSquared': 0.2775785061397933}
# {'Prev': ['^GSPC.prev', '0063.HK.prev'], 'Today': '0001.HK', 'Params': 0.6553115401365868, 'TValues': 9.047762655451063, 'RSquared': 0.27226159759463087}
# {'Prev': ['^GSPC.prev', '0064.HK.prev'], 'Today': '0001.HK', 'Params': 0.678233210261508, 'TValues': 9.296021195581126, 'RSquared': 0.26484237524142884}
# {'Prev': ['^GSPC.prev', '0066.HK.prev'], 'Today': '0001.HK', 'Params': 0.6774397890527726, 'TValues': 9.260937635770464, 'RSquared': 0.26389295417584235}
# {'Prev': ['^GSPC.prev', '0069.HK.prev'], 'Today': '0001.HK', 'Params': 0.6722288213724688, 'TValues': 9.258333504154429, 'RSquared': 0.2631649899120987}
# {'Prev': ['^GSPC.prev', '0071.HK.prev'], 'Today': '0001.HK', 'Params': 0.6744118231486884, 'TValues': 9.28282203112071, 'RSquared': 0.2642081319032401}
# {'Prev': ['^GSPC.prev', '0075.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687075268081416, 'TValues': 9.225528113828704, 'RSquared': 0.26302599986534714}
# {'Prev': ['^GSPC.prev', '0078.HK.prev'], 'Today': '0001.HK', 'Params': 0.6883896842245278, 'TValues': 9.22308076863344, 'RSquared': 0.2653087391852854}
# {'Prev': ['^GSPC.prev', '0081.HK.prev'], 'Today': '0001.HK', 'Params': 0.6717430962721309, 'TValues': 9.23732893094507, 'RSquared': 0.2625249573094851}
# {'Prev': ['^GSPC.prev', '0083.HK.prev'], 'Today': '0001.HK', 'Params': 0.6888209595755722, 'TValues': 9.427550518121285, 'RSquared': 0.27028712023692114}
# {'Prev': ['^GSPC.prev', '0085.HK.prev'], 'Today': '0001.HK', 'Params': 0.6812167629939834, 'TValues': 9.410818904000863, 'RSquared': 0.2711886100365585}
# {'Prev': ['^GSPC.prev', '0086.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687844334470621, 'TValues': 9.166663786588055, 'RSquared': 0.2620587711046537}
# {'Prev': ['^GSPC.prev', '0087.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687406833190258, 'TValues': 9.248453858310299, 'RSquared': 0.26640320673938256}
# {'Prev': ['^GSPC.prev', '0088.HK.prev'], 'Today': '0001.HK', 'Params': 0.6659617834181972, 'TValues': 9.258326179882662, 'RSquared': 0.27440828970864006}
# {'Prev': ['^GSPC.prev', '0089.HK.prev'], 'Today': '0001.HK', 'Params': 0.6780777982155478, 'TValues': 9.373446118300055, 'RSquared': 0.2697857779590003}
# {'Prev': ['^GSPC.prev', '0093.HK.prev'], 'Today': '0001.HK', 'Params': 0.673240376249206, 'TValues': 9.256075483022492, 'RSquared': 0.26315323096549326}
# {'Prev': ['^GSPC.prev', '0095.HK.prev'], 'Today': '0001.HK', 'Params': 0.6725912101663729, 'TValues': 9.290539357465025, 'RSquared': 0.2657217286132021}
# {'Prev': ['^GSPC.prev', '0096.HK.prev'], 'Today': '0001.HK', 'Params': 0.6712342037840646, 'TValues': 9.247002242716706, 'RSquared': 0.262690291757429}
# {'Prev': ['^GSPC.prev', '0097.HK.prev'], 'Today': '0001.HK', 'Params': 0.6693897347482063, 'TValues': 9.232152305030528, 'RSquared': 0.2623371689424051}
# {'Prev': ['^GSPC.prev', '0098.HK.prev'], 'Today': '0001.HK', 'Params': 0.6690479720877914, 'TValues': 9.187507101347698, 'RSquared': 0.26204863510923915}
# {'Prev': ['^GSPC.prev', '0099.HK.prev'], 'Today': '0001.HK', 'Params': 0.6685000345599099, 'TValues': 9.117204085177693, 'RSquared': 0.2620608271140872}
# {'Prev': ['^GSPC.prev', '0101.HK.prev'], 'Today': '0001.HK', 'Params': 0.6789763368358226, 'TValues': 9.315489466268744, 'RSquared': 0.26556480348771516}
# {'Prev': ['^GSPC.prev', '0102.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691452053751332, 'TValues': 9.23106796283382, 'RSquared': 0.2627566113496139}
# {'Prev': ['^GSPC.prev', '0105.HK.prev'], 'Today': '0001.HK', 'Params': 0.6713121801769675, 'TValues': 9.197570582890167, 'RSquared': 0.26218731899219505}
# {'Prev': ['^GSPC.prev', '0106.HK.prev'], 'Today': '0001.HK', 'Params': 0.6694581402077111, 'TValues': 9.231345561046147, 'RSquared': 0.2620518172970959}
# {'Prev': ['^GSPC.prev', '0107.HK.prev'], 'Today': '0001.HK', 'Params': 0.678673066350701, 'TValues': 9.365522637837852, 'RSquared': 0.26864716135746036}
# {'Prev': ['^GSPC.prev', '0108.HK.prev'], 'Today': '0001.HK', 'Params': 0.6694359056598538, 'TValues': 9.239592555708843, 'RSquared': 0.26341438619896684}
# {'Prev': ['^GSPC.prev', '0112.HK.prev'], 'Today': '0001.HK', 'Params': 0.6791800807614851, 'TValues': 9.417348941126086, 'RSquared': 0.27362298915576255}
# {'Prev': ['^GSPC.prev', '0113.HK.prev'], 'Today': '0001.HK', 'Params': 0.6682642286992362, 'TValues': 9.169781995913821, 'RSquared': 0.26212141650094767}
# {'Prev': ['^GSPC.prev', '0116.HK.prev'], 'Today': '0001.HK', 'Params': 0.6771531424628603, 'TValues': 9.28696326589592, 'RSquared': 0.26446326980338075}
# {'Prev': ['^GSPC.prev', '0119.HK.prev'], 'Today': '0001.HK', 'Params': 0.6811991291630537, 'TValues': 9.269041748673164, 'RSquared': 0.26466239287856197}
# {'Prev': ['^GSPC.prev', '0120.HK.prev'], 'Today': '0001.HK', 'Params': 0.6699801726226566, 'TValues': 9.216151667905178, 'RSquared': 0.2620673608318784}
# {'Prev': ['^GSPC.prev', '0123.HK.prev'], 'Today': '0001.HK', 'Params': 0.6711630368381398, 'TValues': 9.189910657122123, 'RSquared': 0.2621532230121941}
# {'Prev': ['^GSPC.prev', '0124.HK.prev'], 'Today': '0001.HK', 'Params': 0.6776203256742217, 'TValues': 9.223899661851135, 'RSquared': 0.26341865118376595}
# {'Prev': ['^GSPC.prev', '0126.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695054023866784, 'TValues': 9.231409621060132, 'RSquared': 0.26204252971393294}
# {'Prev': ['^GSPC.prev', '0127.HK.prev'], 'Today': '0001.HK', 'Params': 0.675624023433269, 'TValues': 9.291320315098641, 'RSquared': 0.2645481550419132}
# {'Prev': ['^GSPC.prev', '0128.HK.prev'], 'Today': '0001.HK', 'Params': 0.6638257033027051, 'TValues': 9.101839821535844, 'RSquared': 0.2634336332823778}
# {'Prev': ['^GSPC.prev', '0129.HK.prev'], 'Today': '0001.HK', 'Params': 0.6844211815927657, 'TValues': 9.467176191816854, 'RSquared': 0.2743454975961209}
# {'Prev': ['^GSPC.prev', '0131.HK.prev'], 'Today': '0001.HK', 'Params': 0.6726048175860025, 'TValues': 9.158768154474954, 'RSquared': 0.262259150800472}
# {'Prev': ['^GSPC.prev', '0133.HK.prev'], 'Today': '0001.HK', 'Params': 0.6758842152111388, 'TValues': 9.301333928187066, 'RSquared': 0.26501886565236}
# {'Prev': ['^GSPC.prev', '0135.HK.prev'], 'Today': '0001.HK', 'Params': 0.6888738720784988, 'TValues': 9.612229043590123, 'RSquared': 0.2859061235715421}
# {'Prev': ['^GSPC.prev', '0142.HK.prev'], 'Today': '0001.HK', 'Params': 0.6704821289521727, 'TValues': 9.22861981820929, 'RSquared': 0.2621919540624854}
# {'Prev': ['^GSPC.prev', '0144.HK.prev'], 'Today': '0001.HK', 'Params': 0.6829633210374586, 'TValues': 9.382229129790213, 'RSquared': 0.2685089554785689}
# {'Prev': ['^GSPC.prev', '0147.HK.prev'], 'Today': '0001.HK', 'Params': 0.6689959065758497, 'TValues': 9.224783486577635, 'RSquared': 0.2623382577307649}
# {'Prev': ['^GSPC.prev', '0148.HK.prev'], 'Today': '0001.HK', 'Params': 0.6720266705322009, 'TValues': 9.226717418083016, 'RSquared': 0.26244961086412977}
# {'Prev': ['^GSPC.prev', '0149.HK.prev'], 'Today': '0001.HK', 'Params': 0.6681754859700297, 'TValues': 9.216359471616142, 'RSquared': 0.26313634320343837}
# {'Prev': ['^GSPC.prev', '0151.HK.prev'], 'Today': '0001.HK', 'Params': 0.6633163213105454, 'TValues': 9.235251708277735, 'RSquared': 0.2771948073875541}
# {'Prev': ['^GSPC.prev', '0152.HK.prev'], 'Today': '0001.HK', 'Params': 0.6734764432685472, 'TValues': 9.206573334151578, 'RSquared': 0.26255227296189876}
# {'Prev': ['^GSPC.prev', '0154.HK.prev'], 'Today': '0001.HK', 'Params': 0.6698091963170675, 'TValues': 9.251083410577985, 'RSquared': 0.26444371052865356}
# {'Prev': ['^GSPC.prev', '0156.HK.prev'], 'Today': '0001.HK', 'Params': 0.6794999196419995, 'TValues': 9.347649518055206, 'RSquared': 0.26708451275675116}
# {'Prev': ['^GSPC.prev', '0157.HK.prev'], 'Today': '0001.HK', 'Params': 0.6703834210874602, 'TValues': 9.2649004566383, 'RSquared': 0.26546216189782723}
# {'Prev': ['^GSPC.prev', '0158.HK.prev'], 'Today': '0001.HK', 'Params': 0.6673864074340738, 'TValues': 9.169766593567985, 'RSquared': 0.26236779416127143}
# {'Prev': ['^GSPC.prev', '0159.HK.prev'], 'Today': '0001.HK', 'Params': 0.6699337112028337, 'TValues': 9.235952059573032, 'RSquared': 0.2622261249201815}
# {'Prev': ['^GSPC.prev', '0160.HK.prev'], 'Today': '0001.HK', 'Params': 0.6708938834733329, 'TValues': 9.260659011534058, 'RSquared': 0.2640071288778233}
# {'Prev': ['^GSPC.prev', '0165.HK.prev'], 'Today': '0001.HK', 'Params': 0.6746723545732021, 'TValues': 9.264008296531559, 'RSquared': 0.26353917896670553}
# {'Prev': ['^GSPC.prev', '0168.HK.prev'], 'Today': '0001.HK', 'Params': 0.6769663044672888, 'TValues': 9.329939329587607, 'RSquared': 0.26657580647805246}
# {'Prev': ['^GSPC.prev', '0169.HK.prev'], 'Today': '0001.HK', 'Params': 0.669638066598617, 'TValues': 9.241114981166504, 'RSquared': 0.26322225111137354}
# {'Prev': ['^GSPC.prev', '0173.HK.prev'], 'Today': '0001.HK', 'Params': 0.6728013050156813, 'TValues': 9.164245770527081, 'RSquared': 0.2622937598760918}
# {'Prev': ['^GSPC.prev', '0175.HK.prev'], 'Today': '0001.HK', 'Params': 0.6784053287053786, 'TValues': 9.298848426214953, 'RSquared': 0.2649461927537199}
# {'Prev': ['^GSPC.prev', '0177.HK.prev'], 'Today': '0001.HK', 'Params': 0.6703411561038186, 'TValues': 9.160892049097226, 'RSquared': 0.2620606698090967}
# {'Prev': ['^GSPC.prev', '0178.HK.prev'], 'Today': '0001.HK', 'Params': 0.6829822533518177, 'TValues': 9.394917537907153, 'RSquared': 0.269253302749879}
# {'Prev': ['^GSPC.prev', '0179.HK.prev'], 'Today': '0001.HK', 'Params': 0.6758068987001293, 'TValues': 9.317348597172664, 'RSquared': 0.266073179508039}
# {'Prev': ['^GSPC.prev', '0180.HK.prev'], 'Today': '0001.HK', 'Params': 0.6693875992905072, 'TValues': 9.22604355860188, 'RSquared': 0.2620403834707773}
# {'Prev': ['^GSPC.prev', '0182.HK.prev'], 'Today': '0001.HK', 'Params': 0.6795468905795387, 'TValues': 9.390358912415413, 'RSquared': 0.27037037055386526}
# {'Prev': ['^GSPC.prev', '0184.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695479153639339, 'TValues': 9.232544620800047, 'RSquared': 0.26209083313298576}
# {'Prev': ['^GSPC.prev', '0185.HK.prev'], 'Today': '0001.HK', 'Params': 0.6812550878909878, 'TValues': 9.385953340848866, 'RSquared': 0.2691377041313311}
# {'Prev': ['^GSPC.prev', '0190.HK.prev'], 'Today': '0001.HK', 'Params': 0.6821245264437701, 'TValues': 9.25638048624832, 'RSquared': 0.26462241096605243}
# {'Prev': ['^GSPC.prev', '0191.HK.prev'], 'Today': '0001.HK', 'Params': 0.6827135723888069, 'TValues': 9.41209858842296, 'RSquared': 0.2705337004877467}
# {'Prev': ['^GSPC.prev', '0194.HK.prev'], 'Today': '0001.HK', 'Params': 0.6721616337960897, 'TValues': 9.157184081791698, 'RSquared': 0.2622076795890219}
# {'Prev': ['^GSPC.prev', '0195.HK.prev'], 'Today': '0001.HK', 'Params': 0.6689130098899589, 'TValues': 9.199047376476639, 'RSquared': 0.26206953599989535}
# {'Prev': ['^GSPC.prev', '0199.HK.prev'], 'Today': '0001.HK', 'Params': 0.6784250606195423, 'TValues': 9.474983305277261, 'RSquared': 0.28228295689989635}
# {'Prev': ['^GSPC.prev', '0200.HK.prev'], 'Today': '0001.HK', 'Params': 0.6727292970465989, 'TValues': 9.229746874293662, 'RSquared': 0.2626056830174094}
# {'Prev': ['^GSPC.prev', '0201.HK.prev'], 'Today': '0001.HK', 'Params': 0.6725209811483484, 'TValues': 9.129105548601704, 'RSquared': 0.2622056675269585}
# {'Prev': ['^GSPC.prev', '0202.HK.prev'], 'Today': '0001.HK', 'Params': 0.6632856889027872, 'TValues': 9.177116875180023, 'RSquared': 0.2692664574715351}
# {'Prev': ['^GSPC.prev', '0206.HK.prev'], 'Today': '0001.HK', 'Params': 0.6645513178075033, 'TValues': 9.123024437959923, 'RSquared': 0.2633549353764132}
# {'Prev': ['^GSPC.prev', '0207.HK.prev'], 'Today': '0001.HK', 'Params': 0.6733777454157326, 'TValues': 9.370686502921723, 'RSquared': 0.27588781881500324}
# {'Prev': ['^GSPC.prev', '0208.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695568461557126, 'TValues': 9.230287560993798, 'RSquared': 0.2620447863780222}
# {'Prev': ['^GSPC.prev', '0212.HK.prev'], 'Today': '0001.HK', 'Params': 0.6672062639139846, 'TValues': 9.152856400113397, 'RSquared': 0.2623145354071401}
# {'Prev': ['^GSPC.prev', '0213.HK.prev'], 'Today': '0001.HK', 'Params': 0.6688289179518618, 'TValues': 9.313756432389333, 'RSquared': 0.2764239759156474}
# {'Prev': ['^GSPC.prev', '0214.HK.prev'], 'Today': '0001.HK', 'Params': 0.6724627945264584, 'TValues': 9.243074630198837, 'RSquared': 0.262745211488562}
# {'Prev': ['^GSPC.prev', '0215.HK.prev'], 'Today': '0001.HK', 'Params': 0.6715429524089358, 'TValues': 9.245810813823336, 'RSquared': 0.2626737604036774}
# {'Prev': ['^GSPC.prev', '0216.HK.prev'], 'Today': '0001.HK', 'Params': 0.6681902919806724, 'TValues': 9.23469396478749, 'RSquared': 0.2655725001062831}
# {'Prev': ['^GSPC.prev', '0217.HK.prev'], 'Today': '0001.HK', 'Params': 0.6758828564947139, 'TValues': 9.284581659004408, 'RSquared': 0.26428498715912696}
# {'Prev': ['^GSPC.prev', '0218.HK.prev'], 'Today': '0001.HK', 'Params': 0.6772188515566934, 'TValues': 9.383258853343301, 'RSquared': 0.27173111251236404}
# {'Prev': ['^GSPC.prev', '0219.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691845561655597, 'TValues': 9.22546420358961, 'RSquared': 0.2621214190521599}
# {'Prev': ['^GSPC.prev', '0220.HK.prev'], 'Today': '0001.HK', 'Params': 0.6730600879749586, 'TValues': 9.233520325331801, 'RSquared': 0.2627081528347802}
# {'Prev': ['^GSPC.prev', '0222.HK.prev'], 'Today': '0001.HK', 'Params': 0.6702642790531874, 'TValues': 9.303221673282511, 'RSquared': 0.2716839919541939}
# {'Prev': ['^GSPC.prev', '0224.HK.prev'], 'Today': '0001.HK', 'Params': 0.6811250639366558, 'TValues': 9.369112793857932, 'RSquared': 0.2680578343154745}
# {'Prev': ['^GSPC.prev', '0225.HK.prev'], 'Today': '0001.HK', 'Params': 0.667971478953608, 'TValues': 9.20745977717321, 'RSquared': 0.2627893958730382}
# {'Prev': ['^GSPC.prev', '0226.HK.prev'], 'Today': '0001.HK', 'Params': 0.6772824932420416, 'TValues': 9.43462180934901, 'RSquared': 0.2784620667099318}
# {'Prev': ['^GSPC.prev', '0227.HK.prev'], 'Today': '0001.HK', 'Params': 0.6700717043754588, 'TValues': 9.257754210630623, 'RSquared': 0.2649602330499711}
# {'Prev': ['^GSPC.prev', '0230.HK.prev'], 'Today': '0001.HK', 'Params': 0.6715033188323757, 'TValues': 9.171228175398822, 'RSquared': 0.26216016180955626}
# {'Prev': ['^GSPC.prev', '0232.HK.prev'], 'Today': '0001.HK', 'Params': 0.6750802500959074, 'TValues': 9.308877485037183, 'RSquared': 0.26571913978818185}
# {'Prev': ['^GSPC.prev', '0234.HK.prev'], 'Today': '0001.HK', 'Params': 0.6660147629858764, 'TValues': 9.164276441812975, 'RSquared': 0.26322277950206163}
# {'Prev': ['^GSPC.prev', '0237.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687312307347028, 'TValues': 9.240487382602383, 'RSquared': 0.2651807279948918}
# {'Prev': ['^GSPC.prev', '0239.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691952152451324, 'TValues': 9.221742498077862, 'RSquared': 0.26206932683227413}
# {'Prev': ['^GSPC.prev', '0240.HK.prev'], 'Today': '0001.HK', 'Params': 0.6626628195647556, 'TValues': 9.1562990365472, 'RSquared': 0.26824486030706474}
# {'Prev': ['^GSPC.prev', '0241.HK.prev'], 'Today': '0001.HK', 'Params': 0.6723417373229665, 'TValues': 9.239432266665574, 'RSquared': 0.26266209552126074}
# {'Prev': ['^GSPC.prev', '0242.HK.prev'], 'Today': '0001.HK', 'Params': 0.6696310033732278, 'TValues': 9.107184155911893, 'RSquared': 0.26203671758922154}
# {'Prev': ['^GSPC.prev', '0245.HK.prev'], 'Today': '0001.HK', 'Params': 0.6664408149345369, 'TValues': 9.171496324121126, 'RSquared': 0.26304135641564175}
# {'Prev': ['^GSPC.prev', '0247.HK.prev'], 'Today': '0001.HK', 'Params': 0.6697067347146186, 'TValues': 9.22248512754061, 'RSquared': 0.26204852395444134}
# {'Prev': ['^GSPC.prev', '0250.HK.prev'], 'Today': '0001.HK', 'Params': 0.6759881900444067, 'TValues': 9.305615232500756, 'RSquared': 0.2652407740250835}
# {'Prev': ['^GSPC.prev', '0251.HK.prev'], 'Today': '0001.HK', 'Params': 0.6662967615503081, 'TValues': 9.201465712518397, 'RSquared': 0.2654957131018906}
# {'Prev': ['^GSPC.prev', '0252.HK.prev'], 'Today': '0001.HK', 'Params': 0.6702493855020164, 'TValues': 9.429298914179675, 'RSquared': 0.2910431698394964}
# {'Prev': ['^GSPC.prev', '0255.HK.prev'], 'Today': '0001.HK', 'Params': 0.6713831731882259, 'TValues': 9.321036874951458, 'RSquared': 0.27216700786352654}
# {'Prev': ['^GSPC.prev', '0256.HK.prev'], 'Today': '0001.HK', 'Params': 0.6549156820587794, 'TValues': 8.984844077654225, 'RSquared': 0.2684974080609578}
# {'Prev': ['^GSPC.prev', '0257.HK.prev'], 'Today': '0001.HK', 'Params': 0.6762797335272639, 'TValues': 9.228956173115504, 'RSquared': 0.26323319304112436}
# {'Prev': ['^GSPC.prev', '0258.HK.prev'], 'Today': '0001.HK', 'Params': 0.6649209117139998, 'TValues': 9.088014650153404, 'RSquared': 0.2626820300278111}
# {'Prev': ['^GSPC.prev', '0259.HK.prev'], 'Today': '0001.HK', 'Params': 0.6661797986062261, 'TValues': 9.151197858515278, 'RSquared': 0.26276878168214}
# {'Prev': ['^GSPC.prev', '0261.HK.prev'], 'Today': '0001.HK', 'Params': 0.6706318267172791, 'TValues': 9.254131412159431, 'RSquared': 0.2634986871453283}
# {'Prev': ['^GSPC.prev', '0265.HK.prev'], 'Today': '0001.HK', 'Params': 0.67283228886531, 'TValues': 9.248466508554015, 'RSquared': 0.26291210354960437}
# {'Prev': ['^GSPC.prev', '0266.HK.prev'], 'Today': '0001.HK', 'Params': 0.6682536118332543, 'TValues': 9.102317982011224, 'RSquared': 0.2620708973013912}
# {'Prev': ['^GSPC.prev', '0267.HK.prev'], 'Today': '0001.HK', 'Params': 0.6739890060455831, 'TValues': 9.238216963575796, 'RSquared': 0.26293470191843504}
# {'Prev': ['^GSPC.prev', '0268.HK.prev'], 'Today': '0001.HK', 'Params': 0.6721246422685108, 'TValues': 9.257783940845266, 'RSquared': 0.26314349233199397}
# {'Prev': ['^GSPC.prev', '0270.HK.prev'], 'Today': '0001.HK', 'Params': 0.6776097843675037, 'TValues': 9.383677635751782, 'RSquared': 0.27134685743727327}
# {'Prev': ['^GSPC.prev', '0271.HK.prev'], 'Today': '0001.HK', 'Params': 0.6591175177872297, 'TValues': 9.032219775201105, 'RSquared': 0.2656198999172672}
# {'Prev': ['^GSPC.prev', '0272.HK.prev'], 'Today': '0001.HK', 'Params': 0.6663929033728035, 'TValues': 9.088315204925445, 'RSquared': 0.2622808093835841}
# {'Prev': ['^GSPC.prev', '0273.HK.prev'], 'Today': '0001.HK', 'Params': 0.669693486498356, 'TValues': 9.228810298321172, 'RSquared': 0.2620593323438678}
# {'Prev': ['^GSPC.prev', '0278.HK.prev'], 'Today': '0001.HK', 'Params': 0.6714909389291696, 'TValues': 9.21588385836587, 'RSquared': 0.26228051739453206}
# {'Prev': ['^GSPC.prev', '0281.HK.prev'], 'Today': '0001.HK', 'Params': 0.6711311934598173, 'TValues': 9.285908047375253, 'RSquared': 0.2672712381081962}
# {'Prev': ['^GSPC.prev', '0282.HK.prev'], 'Today': '0001.HK', 'Params': 0.6688770308816436, 'TValues': 9.094894629015759, 'RSquared': 0.2620433849907401}
# {'Prev': ['^GSPC.prev', '0285.HK.prev'], 'Today': '0001.HK', 'Params': 0.6769891178695262, 'TValues': 9.236101441014307, 'RSquared': 0.26344262335203483}
# {'Prev': ['^GSPC.prev', '0286.HK.prev'], 'Today': '0001.HK', 'Params': 0.6634604224479004, 'TValues': 9.073998180709056, 'RSquared': 0.26320177471431583}
# {'Prev': ['^GSPC.prev', '0289.HK.prev'], 'Today': '0001.HK', 'Params': 0.6637385534722362, 'TValues': 9.036486211445515, 'RSquared': 0.26275221931759285}
# {'Prev': ['^GSPC.prev', '0291.HK.prev'], 'Today': '0001.HK', 'Params': 0.6690620931337704, 'TValues': 9.23337528035944, 'RSquared': 0.26330169363130884}
# {'Prev': ['^GSPC.prev', '0293.HK.prev'], 'Today': '0001.HK', 'Params': 0.6896116211208645, 'TValues': 9.516761789233643, 'RSquared': 0.27574492359472824}
# {'Prev': ['^GSPC.prev', '0294.HK.prev'], 'Today': '0001.HK', 'Params': 0.6767498621260774, 'TValues': 9.312166685664208, 'RSquared': 0.2654965420748775}
# {'Prev': ['^GSPC.prev', '0295.HK.prev'], 'Today': '0001.HK', 'Params': 0.6678703186249926, 'TValues': 9.186946465510207, 'RSquared': 0.26231958792789467}
# {'Prev': ['^GSPC.prev', '0296.HK.prev'], 'Today': '0001.HK', 'Params': 0.668300501816062, 'TValues': 9.123730623279755, 'RSquared': 0.26207565693141366}
# {'Prev': ['^GSPC.prev', '0298.HK.prev'], 'Today': '0001.HK', 'Params': 0.6751960321879489, 'TValues': 9.303152249083352, 'RSquared': 0.2652588514972395}
# {'Prev': ['^GSPC.prev', '0303.HK.prev'], 'Today': '0001.HK', 'Params': 0.6738379207728888, 'TValues': 9.30519959501656, 'RSquared': 0.2661648763607838}
# {'Prev': ['^GSPC.prev', '0305.HK.prev'], 'Today': '0001.HK', 'Params': 0.654051161891663, 'TValues': 9.00287974686445, 'RSquared': 0.2708795950802132}
# {'Prev': ['^GSPC.prev', '0306.HK.prev'], 'Today': '0001.HK', 'Params': 0.6669385490756108, 'TValues': 9.123540181111048, 'RSquared': 0.26226480900656124}
# {'Prev': ['^GSPC.prev', '0307.HK.prev'], 'Today': '0001.HK', 'Params': 0.6694114913719447, 'TValues': 9.229355472001496, 'RSquared': 0.2620430487292257}
# {'Prev': ['^GSPC.prev', '0308.HK.prev'], 'Today': '0001.HK', 'Params': 0.664070083700373, 'TValues': 9.078549896717087, 'RSquared': 0.2629517801377875}
# {'Prev': ['^GSPC.prev', '0311.HK.prev'], 'Today': '0001.HK', 'Params': 0.6774935733546319, 'TValues': 9.383257213041448, 'RSquared': 0.2714223200413869}
# {'Prev': ['^GSPC.prev', '0312.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691108725127654, 'TValues': 9.195268610399225, 'RSquared': 0.2620471960270393}
# {'Prev': ['^GSPC.prev', '0315.HK.prev'], 'Today': '0001.HK', 'Params': 0.6821929667762343, 'TValues': 9.386554065086704, 'RSquared': 0.26890788766663964}
# {'Prev': ['^GSPC.prev', '0316.HK.prev'], 'Today': '0001.HK', 'Params': 0.669139508654934, 'TValues': 9.235300103172658, 'RSquared': 0.263415845010175}
# {'Prev': ['^GSPC.prev', '0317.HK.prev'], 'Today': '0001.HK', 'Params': 0.672445287341487, 'TValues': 9.106207710925439, 'RSquared': 0.2621759463207094}
# {'Prev': ['^GSPC.prev', '0321.HK.prev'], 'Today': '0001.HK', 'Params': 0.6664771475185647, 'TValues': 9.174300958065473, 'RSquared': 0.2631017984570728}
# {'Prev': ['^GSPC.prev', '0322.HK.prev'], 'Today': '0001.HK', 'Params': 0.6760253958075123, 'TValues': 9.339107384700608, 'RSquared': 0.2679013621792442}
# {'Prev': ['^GSPC.prev', '0323.HK.prev'], 'Today': '0001.HK', 'Params': 0.6810590972638748, 'TValues': 9.365022841204429, 'RSquared': 0.26782750420862045}
# {'Prev': ['^GSPC.prev', '0327.HK.prev'], 'Today': '0001.HK', 'Params': 0.6774840717268058, 'TValues': 9.40332234221785, 'RSquared': 0.27393146576071237}
# {'Prev': ['^GSPC.prev', '0329.HK.prev'], 'Today': '0001.HK', 'Params': 0.6669895010996167, 'TValues': 9.178549119271203, 'RSquared': 0.26274884061142667}
# {'Prev': ['^GSPC.prev', '0330.HK.prev'], 'Today': '0001.HK', 'Params': 0.6688417947729305, 'TValues': 9.201090182658547, 'RSquared': 0.26208430630430235}
# {'Prev': ['^GSPC.prev', '0332.HK.prev'], 'Today': '0001.HK', 'Params': 0.6754396783462887, 'TValues': 9.31765806106029, 'RSquared': 0.26626821919380483}
# {'Prev': ['^GSPC.prev', '0335.HK.prev'], 'Today': '0001.HK', 'Params': 0.6770913811989958, 'TValues': 9.383965270353324, 'RSquared': 0.2719684121121121}
# {'Prev': ['^GSPC.prev', '0336.HK.prev'], 'Today': '0001.HK', 'Params': 0.689643009806792, 'TValues': 9.450608726086237, 'RSquared': 0.2713695796917288}
# {'Prev': ['^GSPC.prev', '0340.HK.prev'], 'Today': '0001.HK', 'Params': 0.673232977456782, 'TValues': 9.295413739268986, 'RSquared': 0.26564170760495387}
# {'Prev': ['^GSPC.prev', '0341.HK.prev'], 'Today': '0001.HK', 'Params': 0.6684632212932935, 'TValues': 9.23765649220068, 'RSquared': 0.2653753094001037}
# {'Prev': ['^GSPC.prev', '0342.HK.prev'], 'Today': '0001.HK', 'Params': 0.6713658172350093, 'TValues': 9.264034446915701, 'RSquared': 0.26389683745005055}
# {'Prev': ['^GSPC.prev', '0345.HK.prev'], 'Today': '0001.HK', 'Params': 0.6752572226176241, 'TValues': 9.2941209542521, 'RSquared': 0.2647073624046774}
# {'Prev': ['^GSPC.prev', '0347.HK.prev'], 'Today': '0001.HK', 'Params': 0.6714356262912382, 'TValues': 9.257524543375107, 'RSquared': 0.26324844125693003}
# {'Prev': ['^GSPC.prev', '0354.HK.prev'], 'Today': '0001.HK', 'Params': 0.67751802702558, 'TValues': 9.309041236376235, 'RSquared': 0.26528956106742685}
# {'Prev': ['^GSPC.prev', '0355.HK.prev'], 'Today': '0001.HK', 'Params': 0.6731473112775497, 'TValues': 9.24284100904901, 'RSquared': 0.2628562683606419}
# {'Prev': ['^GSPC.prev', '0357.HK.prev'], 'Today': '0001.HK', 'Params': 0.6715409640314041, 'TValues': 9.271225102617455, 'RSquared': 0.2645559888488439}
# {'Prev': ['^GSPC.prev', '0358.HK.prev'], 'Today': '0001.HK', 'Params': 0.7071137756822274, 'TValues': 9.698207172727548, 'RSquared': 0.28274744459627377}
# {'Prev': ['^GSPC.prev', '0360.HK.prev'], 'Today': '0001.HK', 'Params': 0.6688974543900205, 'TValues': 9.191666814503549, 'RSquared': 0.26206355147173244}
# {'Prev': ['^GSPC.prev', '0362.HK.prev'], 'Today': '0001.HK', 'Params': 0.6783029681761042, 'TValues': 9.387398954706136, 'RSquared': 0.27107668601231316}
# {'Prev': ['^GSPC.prev', '0363.HK.prev'], 'Today': '0001.HK', 'Params': 0.6712147119144458, 'TValues': 9.242455916518093, 'RSquared': 0.26254325439288595}
# {'Prev': ['^GSPC.prev', '0365.HK.prev'], 'Today': '0001.HK', 'Params': 0.6723970864179717, 'TValues': 9.276061502621163, 'RSquared': 0.26432536761082714}
# {'Prev': ['^GSPC.prev', '0366.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695341928325915, 'TValues': 9.239516737805129, 'RSquared': 0.2631872089940822}
# {'Prev': ['^GSPC.prev', '0367.HK.prev'], 'Today': '0001.HK', 'Params': 0.6709946807685558, 'TValues': 9.246146683516317, 'RSquared': 0.2626534292021965}
# {'Prev': ['^GSPC.prev', '0369.HK.prev'], 'Today': '0001.HK', 'Params': 0.6711807996679902, 'TValues': 9.250529397044659, 'RSquared': 0.2628569456297176}
# {'Prev': ['^GSPC.prev', '0370.HK.prev'], 'Today': '0001.HK', 'Params': 0.7011130590875175, 'TValues': 9.725477939117559, 'RSquared': 0.2872903755770997}
# {'Prev': ['^GSPC.prev', '0371.HK.prev'], 'Today': '0001.HK', 'Params': 0.6775886727110052, 'TValues': 9.139960654252913, 'RSquared': 0.26287058501944904}
# {'Prev': ['^GSPC.prev', '0372.HK.prev'], 'Today': '0001.HK', 'Params': 0.6777181346731262, 'TValues': 9.206267058063997, 'RSquared': 0.26327413797533095}
# {'Prev': ['^GSPC.prev', '0373.HK.prev'], 'Today': '0001.HK', 'Params': 0.6668499781458657, 'TValues': 9.145364122130534, 'RSquared': 0.2623870556341972}
# {'Prev': ['^GSPC.prev', '0374.HK.prev'], 'Today': '0001.HK', 'Params': 0.6666627543752623, 'TValues': 9.24336028050982, 'RSquared': 0.27049654053863137}
# {'Prev': ['^GSPC.prev', '0375.HK.prev'], 'Today': '0001.HK', 'Params': 0.6723740710712787, 'TValues': 9.239242907737953, 'RSquared': 0.2626647018202307}
# {'Prev': ['^GSPC.prev', '0377.HK.prev'], 'Today': '0001.HK', 'Params': 0.6655657958286533, 'TValues': 9.123633723817894, 'RSquared': 0.26273118640526905}
# {'Prev': ['^GSPC.prev', '0383.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695611424650991, 'TValues': 9.233260120878057, 'RSquared': 0.262157335408694}
# {'Prev': ['^GSPC.prev', '0385.HK.prev'], 'Today': '0001.HK', 'Params': 0.6729970014767153, 'TValues': 9.256967370684944, 'RSquared': 0.26315219330435413}
# {'Prev': ['^GSPC.prev', '0386.HK.prev'], 'Today': '0001.HK', 'Params': 0.688889937607672, 'TValues': 9.452215281003939, 'RSquared': 0.2715544356837595}
# {'Prev': ['^GSPC.prev', '0388.HK.prev'], 'Today': '0001.HK', 'Params': 0.678263746508677, 'TValues': 9.3514713058397, 'RSquared': 0.2676951062352527}
# {'Prev': ['^GSPC.prev', '0390.HK.prev'], 'Today': '0001.HK', 'Params': 0.6655558674790446, 'TValues': 9.02929973092017, 'RSquared': 0.26230376804771693}
# {'Prev': ['^GSPC.prev', '0391.HK.prev'], 'Today': '0001.HK', 'Params': 0.6539830786333366, 'TValues': 9.03828496880127, 'RSquared': 0.2739264420146722}
# {'Prev': ['^GSPC.prev', '0392.HK.prev'], 'Today': '0001.HK', 'Params': 0.6738203352482594, 'TValues': 9.254556262228064, 'RSquared': 0.2631932539031743}
# {'Prev': ['^GSPC.prev', '0393.HK.prev'], 'Today': '0001.HK', 'Params': 0.6745964419081203, 'TValues': 9.314531522365812, 'RSquared': 0.26651695459817837}
# {'Prev': ['^GSPC.prev', '0395.HK.prev'], 'Today': '0001.HK', 'Params': 0.6763824288457787, 'TValues': 9.273462341887013, 'RSquared': 0.2640003907512717}
# {'Prev': ['^GSPC.prev', '0398.HK.prev'], 'Today': '0001.HK', 'Params': 0.6761829786467927, 'TValues': 9.285863516145405, 'RSquared': 0.26434795675224676}
# {'Prev': ['^GSPC.prev', '0405.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695211534944816, 'TValues': 9.2355920258261, 'RSquared': 0.2625900880407358}
# {'Prev': ['^GSPC.prev', '0406.HK.prev'], 'Today': '0001.HK', 'Params': 0.6699488051716243, 'TValues': 9.256065355218992, 'RSquared': 0.2649423520204638}
# {'Prev': ['^GSPC.prev', '0410.HK.prev'], 'Today': '0001.HK', 'Params': 0.6697722955306699, 'TValues': 9.208858084364467, 'RSquared': 0.26204537568215824}
# {'Prev': ['^GSPC.prev', '0411.HK.prev'], 'Today': '0001.HK', 'Params': 0.6646168832189001, 'TValues': 9.18947434085334, 'RSquared': 0.2677913363615687}
# {'Prev': ['^GSPC.prev', '0412.HK.prev'], 'Today': '0001.HK', 'Params': 0.668601975503695, 'TValues': 9.217153630130937, 'RSquared': 0.26245006666963555}
# {'Prev': ['^GSPC.prev', '0413.HK.prev'], 'Today': '0001.HK', 'Params': 0.66946194742379, 'TValues': 9.231658484461864, 'RSquared': 0.2620904167375967}
# {'Prev': ['^GSPC.prev', '0419.HK.prev'], 'Today': '0001.HK', 'Params': 0.6738718848662135, 'TValues': 9.322589640461812, 'RSquared': 0.2681965264291103}
# {'Prev': ['^GSPC.prev', '0420.HK.prev'], 'Today': '0001.HK', 'Params': 0.6740159302317617, 'TValues': 9.295503842306445, 'RSquared': 0.2651284104851497}
# {'Prev': ['^GSPC.prev', '0423.HK.prev'], 'Today': '0001.HK', 'Params': 0.6697573436560972, 'TValues': 9.160429053891912, 'RSquared': 0.26203912102859583}
# {'Prev': ['^GSPC.prev', '0425.HK.prev'], 'Today': '0001.HK', 'Params': 0.6546818903033249, 'TValues': 9.042051978731427, 'RSquared': 0.2729352352981118}
# {'Prev': ['^GSPC.prev', '0431.HK.prev'], 'Today': '0001.HK', 'Params': 0.6599528099735958, 'TValues': 9.145605174446962, 'RSquared': 0.27289212257594975}
# {'Prev': ['^GSPC.prev', '0432.HK.prev'], 'Today': '0001.HK', 'Params': 0.6719545705890466, 'TValues': 9.251939037099914, 'RSquared': 0.26290475354114284}
# {'Prev': ['^GSPC.prev', '0435.HK.prev'], 'Today': '0001.HK', 'Params': 0.6770278950816278, 'TValues': 9.333509925802684, 'RSquared': 0.26681855882807537}
# {'Prev': ['^GSPC.prev', '0440.HK.prev'], 'Today': '0001.HK', 'Params': 0.6672085241978258, 'TValues': 9.224878994792837, 'RSquared': 0.2664663612706355}
# {'Prev': ['^GSPC.prev', '0444.HK.prev'], 'Today': '0001.HK', 'Params': 0.6751189581746522, 'TValues': 9.323583811850698, 'RSquared': 0.2670301391543519}
# {'Prev': ['^GSPC.prev', '0445.HK.prev'], 'Today': '0001.HK', 'Params': 0.7014077221075405, 'TValues': 9.483933014938062, 'RSquared': 0.27279937509259145}
# {'Prev': ['^GSPC.prev', '0451.HK.prev'], 'Today': '0001.HK', 'Params': 0.6676465048314826, 'TValues': 9.202029911499693, 'RSquared': 0.26293899083645256}
# {'Prev': ['^GSPC.prev', '0460.HK.prev'], 'Today': '0001.HK', 'Params': 0.6907500132536675, 'TValues': 9.522206964404678, 'RSquared': 0.2756799732848302}
# {'Prev': ['^GSPC.prev', '0464.HK.prev'], 'Today': '0001.HK', 'Params': 0.6700190363567833, 'TValues': 9.232049586389582, 'RSquared': 0.26214308849429524}
# {'Prev': ['^GSPC.prev', '0467.HK.prev'], 'Today': '0001.HK', 'Params': 0.6694398895663995, 'TValues': 9.230953520109873, 'RSquared': 0.2620510640399002}
# {'Prev': ['^GSPC.prev', '0468.HK.prev'], 'Today': '0001.HK', 'Params': 0.668895981383022, 'TValues': 9.21805447566036, 'RSquared': 0.2621759298305737}
# {'Prev': ['^GSPC.prev', '0472.HK.prev'], 'Today': '0001.HK', 'Params': 0.6667868118481135, 'TValues': 9.17309015461179, 'RSquared': 0.2627781648663863}
# {'Prev': ['^GSPC.prev', '0474.HK.prev'], 'Today': '0001.HK', 'Params': 0.7037875607623542, 'TValues': 9.534797003325556, 'RSquared': 0.27475960972857094}
# {'Prev': ['^GSPC.prev', '0480.HK.prev'], 'Today': '0001.HK', 'Params': 0.6725201856446441, 'TValues': 9.268995040000542, 'RSquared': 0.2637114686796319}
# {'Prev': ['^GSPC.prev', '0486.HK.prev'], 'Today': '0001.HK', 'Params': 0.6830099282699155, 'TValues': 9.46955857620146, 'RSquared': 0.2757078595414455}
# {'Prev': ['^GSPC.prev', '0487.HK.prev'], 'Today': '0001.HK', 'Params': 0.6707301157121262, 'TValues': 9.239431384984428, 'RSquared': 0.26240349697491516}
# {'Prev': ['^GSPC.prev', '0488.HK.prev'], 'Today': '0001.HK', 'Params': 0.6736860415020149, 'TValues': 9.205680512491291, 'RSquared': 0.26258153413582297}
# {'Prev': ['^GSPC.prev', '0489.HK.prev'], 'Today': '0001.HK', 'Params': 0.6815640506001872, 'TValues': 9.460349164763553, 'RSquared': 0.27610190045380534}
# {'Prev': ['^GSPC.prev', '0493.HK.prev'], 'Today': '0001.HK', 'Params': 0.6661423239394852, 'TValues': 8.977546433947818, 'RSquared': 0.26217366179493384}
# {'Prev': ['^GSPC.prev', '0496.HK.prev'], 'Today': '0001.HK', 'Params': 0.6769143059247398, 'TValues': 9.409837539006539, 'RSquared': 0.2756008623210212}
# {'Prev': ['^GSPC.prev', '0497.HK.prev'], 'Today': '0001.HK', 'Params': 0.6693418281996901, 'TValues': 9.200646444527623, 'RSquared': 0.26203767599710215}
# {'Prev': ['^GSPC.prev', '0500.HK.prev'], 'Today': '0001.HK', 'Params': 0.67053034246388, 'TValues': 9.230260977800624, 'RSquared': 0.2622155512249259}
# {'Prev': ['^GSPC.prev', '0505.HK.prev'], 'Today': '0001.HK', 'Params': 0.6774339218379698, 'TValues': 9.302136053416637, 'RSquared': 0.26500353280564093}
# {'Prev': ['^GSPC.prev', '0506.HK.prev'], 'Today': '0001.HK', 'Params': 0.6702125263857058, 'TValues': 9.226696550202899, 'RSquared': 0.2621317427316241}
# {'Prev': ['^GSPC.prev', '0508.HK.prev'], 'Today': '0001.HK', 'Params': 0.6626724263956429, 'TValues': 9.164244303134751, 'RSquared': 0.2690998270752143}
# {'Prev': ['^GSPC.prev', '0511.HK.prev'], 'Today': '0001.HK', 'Params': 0.6674181476967778, 'TValues': 9.164316349739163, 'RSquared': 0.26231350847610546}
# {'Prev': ['^GSPC.prev', '0512.HK.prev'], 'Today': '0001.HK', 'Params': 0.6693334731290175, 'TValues': 9.207936227703978, 'RSquared': 0.2620384667950657}
# {'Prev': ['^GSPC.prev', '0517.HK.prev'], 'Today': '0001.HK', 'Params': 0.6814894616049132, 'TValues': 9.28347640516351, 'RSquared': 0.26497525123445975}
# {'Prev': ['^GSPC.prev', '0522.HK.prev'], 'Today': '0001.HK', 'Params': 0.6701131701936383, 'TValues': 9.237526456494749, 'RSquared': 0.2622918599396399}
# {'Prev': ['^GSPC.prev', '0525.HK.prev'], 'Today': '0001.HK', 'Params': 0.6755463101022875, 'TValues': 9.251257472150565, 'RSquared': 0.2634060444828342}
# {'Prev': ['^GSPC.prev', '0526.HK.prev'], 'Today': '0001.HK', 'Params': 0.6689171289516644, 'TValues': 9.217667789966251, 'RSquared': 0.2621554441856524}
# {'Prev': ['^GSPC.prev', '0527.HK.prev'], 'Today': '0001.HK', 'Params': 0.6714797268634212, 'TValues': 9.24374480513852, 'RSquared': 0.2626102516327987}
# {'Prev': ['^GSPC.prev', '0528.HK.prev'], 'Today': '0001.HK', 'Params': 0.6671237277657653, 'TValues': 9.188566558915577, 'RSquared': 0.2629476595907436}
# {'Prev': ['^GSPC.prev', '0529.HK.prev'], 'Today': '0001.HK', 'Params': 0.6725089894777536, 'TValues': 9.287108563459276, 'RSquared': 0.2654019567143918}
# {'Prev': ['^GSPC.prev', '0530.HK.prev'], 'Today': '0001.HK', 'Params': 0.6658500579166644, 'TValues': 9.202922221107881, 'RSquared': 0.2666756104166822}
# {'Prev': ['^GSPC.prev', '0531.HK.prev'], 'Today': '0001.HK', 'Params': 0.666377365310517, 'TValues': 9.013463546874345, 'RSquared': 0.2621777488218391}
# {'Prev': ['^GSPC.prev', '0533.HK.prev'], 'Today': '0001.HK', 'Params': 0.6770610468488693, 'TValues': 9.219124130012775, 'RSquared': 0.26327226142925975}
# {'Prev': ['^GSPC.prev', '0535.HK.prev'], 'Today': '0001.HK', 'Params': 0.6772854586203614, 'TValues': 9.342989197647515, 'RSquared': 0.2674591334035703}
# {'Prev': ['^GSPC.prev', '0536.HK.prev'], 'Today': '0001.HK', 'Params': 0.6713433398627351, 'TValues': 9.247648246666502, 'RSquared': 0.2627186465484588}
# {'Prev': ['^GSPC.prev', '0538.HK.prev'], 'Today': '0001.HK', 'Params': 0.6576459051791848, 'TValues': 8.921386019401615, 'RSquared': 0.2642826774757281}
# {'Prev': ['^GSPC.prev', '0542.HK.prev'], 'Today': '0001.HK', 'Params': 0.6712715652118363, 'TValues': 9.294749921964467, 'RSquared': 0.26835295703786965}
# {'Prev': ['^GSPC.prev', '0543.HK.prev'], 'Today': '0001.HK', 'Params': 0.6672435129165506, 'TValues': 9.224516431617626, 'RSquared': 0.2663316058822227}
# {'Prev': ['^GSPC.prev', '0546.HK.prev'], 'Today': '0001.HK', 'Params': 0.6841598053277862, 'TValues': 9.500889693063503, 'RSquared': 0.2780720212682116}
# {'Prev': ['^GSPC.prev', '0547.HK.prev'], 'Today': '0001.HK', 'Params': 0.678622927204666, 'TValues': 9.330069500231632, 'RSquared': 0.26623282851379637}
# {'Prev': ['^GSPC.prev', '0551.HK.prev'], 'Today': '0001.HK', 'Params': 0.6667920652452177, 'TValues': 9.22754962735247, 'RSquared': 0.26784051587039004}
# {'Prev': ['^GSPC.prev', '0552.HK.prev'], 'Today': '0001.HK', 'Params': 0.6696585148592703, 'TValues': 9.298895064788706, 'RSquared': 0.2722967975774194}
# {'Prev': ['^GSPC.prev', '0553.HK.prev'], 'Today': '0001.HK', 'Params': 0.6720543383455087, 'TValues': 9.281569024029446, 'RSquared': 0.2652369638155475}
# {'Prev': ['^GSPC.prev', '0554.HK.prev'], 'Today': '0001.HK', 'Params': 0.6744984899723747, 'TValues': 9.25113101742835, 'RSquared': 0.26322897685989377}
# {'Prev': ['^GSPC.prev', '0560.HK.prev'], 'Today': '0001.HK', 'Params': 0.6663856313257536, 'TValues': 9.129930155668761, 'RSquared': 0.26244725082923326}
# {'Prev': ['^GSPC.prev', '0563.HK.prev'], 'Today': '0001.HK', 'Params': 0.6624487959360079, 'TValues': 9.050788602885984, 'RSquared': 0.26343851254956485}
# {'Prev': ['^GSPC.prev', '0565.HK.prev'], 'Today': '0001.HK', 'Params': 0.6649511820610252, 'TValues': 9.135134010880387, 'RSquared': 0.2633300222063164}
# {'Prev': ['^GSPC.prev', '0570.HK.prev'], 'Today': '0001.HK', 'Params': 0.6758452576705529, 'TValues': 9.289270288595297, 'RSquared': 0.2644607355915871}
# {'Prev': ['^GSPC.prev', '0571.HK.prev'], 'Today': '0001.HK', 'Params': 0.6679439053081027, 'TValues': 9.240515965858311, 'RSquared': 0.26703955489512243}
# {'Prev': ['^GSPC.prev', '0573.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695628023592963, 'TValues': 9.23826399137656, 'RSquared': 0.2629270285435422}
# {'Prev': ['^GSPC.prev', '0576.HK.prev'], 'Today': '0001.HK', 'Params': 0.6768555103573545, 'TValues': 9.32898032883168, 'RSquared': 0.26654519689441014}
# {'Prev': ['^GSPC.prev', '0580.HK.prev'], 'Today': '0001.HK', 'Params': 0.6793123510244522, 'TValues': 9.387457179790397, 'RSquared': 0.27025484429344404}
# {'Prev': ['^GSPC.prev', '0581.HK.prev'], 'Today': '0001.HK', 'Params': 0.6691218079821177, 'TValues': 9.205828806620154, 'RSquared': 0.26205170731802585}
# {'Prev': ['^GSPC.prev', '0583.HK.prev'], 'Today': '0001.HK', 'Params': 0.6658317564042688, 'TValues': 9.117842995386546, 'RSquared': 0.26256300965187673}
# {'Prev': ['^GSPC.prev', '0585.HK.prev'], 'Today': '0001.HK', 'Params': 0.681252286213919, 'TValues': 9.407734227708122, 'RSquared': 0.270889604660039}
# {'Prev': ['^GSPC.prev', '0587.HK.prev'], 'Today': '0001.HK', 'Params': 0.6781493807348263, 'TValues': 9.316279319817419, 'RSquared': 0.26559563004362197}
# {'Prev': ['^GSPC.prev', '0588.HK.prev'], 'Today': '0001.HK', 'Params': 0.6687818229987765, 'TValues': 9.17461947775152, 'RSquared': 0.2620627984303632}
# {'Prev': ['^GSPC.prev', '0590.HK.prev'], 'Today': '0001.HK', 'Params': 0.679417521528815, 'TValues': 9.218292494543716, 'RSquared': 0.26368071034261775}
# {'Prev': ['^GSPC.prev', '0593.HK.prev'], 'Today': '0001.HK', 'Params': 0.6705348877736579, 'TValues': 9.24684900401795, 'RSquared': 0.2627965664323494}
# {'Prev': ['^GSPC.prev', '0596.HK.prev'], 'Today': '0001.HK', 'Params': 0.6775810737783861, 'TValues': 9.403061704622571, 'RSquared': 0.27377095616075253}
# {'Prev': ['^GSPC.prev', '0598.HK.prev'], 'Today': '0001.HK', 'Params': 0.6597700061138935, 'TValues': 9.076412726636383, 'RSquared': 0.26688692488560684}
# {'Prev': ['^GSPC.prev', '0601.HK.prev'], 'Today': '0001.HK', 'Params': 0.680006392806707, 'TValues': 9.184641372323162, 'RSquared': 0.26350031447716626}
# {'Prev': ['^GSPC.prev', '0603.HK.prev'], 'Today': '0001.HK', 'Params': 0.694977905518583, 'TValues': 9.38795217899891, 'RSquared': 0.2692992657056673}
# {'Prev': ['^GSPC.prev', '0604.HK.prev'], 'Today': '0001.HK', 'Params': 0.6765549760115127, 'TValues': 9.2164520581456, 'RSquared': 0.26315819517941363}
# {'Prev': ['^GSPC.prev', '0605.HK.prev'], 'Today': '0001.HK', 'Params': 0.6727647472691591, 'TValues': 9.258520649005172, 'RSquared': 0.2631841339489548}
# {'Prev': ['^GSPC.prev', '0610.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695128107885472, 'TValues': 9.232007005471155, 'RSquared': 0.26206343913039276}
# {'Prev': ['^GSPC.prev', '0611.HK.prev'], 'Today': '0001.HK', 'Params': 0.6723285668591812, 'TValues': 9.265919265034734, 'RSquared': 0.26356016921691616}
# {'Prev': ['^GSPC.prev', '0613.HK.prev'], 'Today': '0001.HK', 'Params': 0.6716089568888585, 'TValues': 9.211177127004397, 'RSquared': 0.2622760002009553}
# {'Prev': ['^GSPC.prev', '0617.HK.prev'], 'Today': '0001.HK', 'Params': 0.6892645111313603, 'TValues': 9.495462478268637, 'RSquared': 0.27425560682050665}
# {'Prev': ['^GSPC.prev', '0618.HK.prev'], 'Today': '0001.HK', 'Params': 0.6685531821537931, 'TValues': 9.218405970141427, 'RSquared': 0.26260771310143827}
# {'Prev': ['^GSPC.prev', '0620.HK.prev'], 'Today': '0001.HK', 'Params': 0.6695677403508935, 'TValues': 9.207013211079307, 'RSquared': 0.26203718064226544}
# {'Prev': ['^GSPC.prev', '0621.HK.prev'], 'Today': '0001.HK', 'Params': 0.6815583047488647, 'TValues': 9.42050559959927, 'RSquared': 0.27186733261413887}
# {'Prev': ['^GSPC.prev', '0622.HK.prev'], 'Today': '0001.HK', 'Params': 0.6636485622824478, 'TValues': 9.269326144095638, 'RSquared': 0.2814640962728834}
# {'Prev': ['^GSPC.prev', '0623.HK.prev'], 'Today': '0001.HK', 'Params': 0.6729519685825568, 'TValues': 9.17717378053387, 'RSquared': 0.2623465965369227}
# {'Prev': ['^GSPC.prev', '0626.HK.prev'], 'Today': '0001.HK', 'Params': 0.6693582874080095, 'TValues': 9.230670413620208, 'RSquared': 0.2621942176815405}
# {'Prev': ['^GSPC.prev', '0628.HK.prev'], 'Today': '0001.HK', 'Params': 0.6686638199911382, 'TValues': 9.220376635790753, 'RSquared': 0.26256994401493017}
# {'Prev': ['^GSPC.prev', '0631.HK.prev'], 'Today': '0001.HK', 'Params': 0.6770865032285618, 'TValues': 9.2758913123408, 'RSquared': 0.26415400262608857}
# {'Prev': ['^GSPC.prev', '0635.HK.prev'], 'Today': '0001.HK', 'Params': 0.6681003125076838, 'TValues': 9.219532650561314, 'RSquared': 0.26365320367659606}
# ...
# {'Prev': ['^GSPC.prev', 'CRM.prev'], 'Today': '0001.HK', 'Params': 0.7005513816000615, 'TValues': 7.253541583868899, 'RSquared': 0.2627646534483731}
# {'Prev': ['^GSPC.prev', 'DDD.prev'], 'Today': '0001.HK', 'Params': 0.6283980879990256, 'TValues': 7.077087833630218, 'RSquared': 0.26399641691928777}
# {'Prev': ['^GSPC.prev', 'DE.prev'], 'Today': '0001.HK', 'Params': 0.4449510892805624, 'TValues': 3.1125071829079376, 'RSquared': 0.27206284052185936}
# {'Prev': ['^GSPC.prev', 'DIS.prev'], 'Today': '0001.HK', 'Params': 0.4757119034994433, 'TValues': 3.450739744033497, 'RSquared': 0.2703046735236412}
# {'Prev': ['^GSPC.prev', 'DLB.prev'], 'Today': '0001.HK', 'Params': 0.5473821575162499, 'TValues': 6.14157540050638, 'RSquared': 0.2780571990811236}
# {'Prev': ['^GSPC.prev', 'DLR.prev'], 'Today': '0001.HK', 'Params': 0.779110915398913, 'TValues': 7.507061086634737, 'RSquared': 0.26862637644673104}
# {'Prev': ['^GSPC.prev', 'EA.prev'], 'Today': '0001.HK', 'Params': 0.7674511522269993, 'TValues': 7.421279813435169, 'RSquared': 0.26739076479191526}
# {'Prev': ['^GSPC.prev', 'EBAY.prev'], 'Today': '0001.HK', 'Params': 0.6169885945895393, 'TValues': 5.376048934591259, 'RSquared': 0.2631039721656504}
# {'Prev': ['^GSPC.prev', 'ERJ.prev'], 'Today': '0001.HK', 'Params': 0.596572037743955, 'TValues': 5.82018111633083, 'RSquared': 0.26512424121144706}
# {'Prev': ['^GSPC.prev', 'F.prev'], 'Today': '0001.HK', 'Params': 0.5340215667283181, 'TValues': 4.31926123830879, 'RSquared': 0.26759779397569894}
# {'Prev': ['^GSPC.prev', 'FDX.prev'], 'Today': '0001.HK', 'Params': 0.4142410199413209, 'TValues': 3.162391951075429, 'RSquared': 0.27833841191993036}
# {'Prev': ['^GSPC.prev', 'FFIV.prev'], 'Today': '0001.HK', 'Params': 0.6084728039299077, 'TValues': 6.75064740271143, 'RSquared': 0.2659692980118723}
# {'Prev': ['^GSPC.prev', 'FORM.prev'], 'Today': '0001.HK', 'Params': 0.6342614820159692, 'TValues': 6.886200621826506, 'RSquared': 0.26321336339942314}
# {'Prev': ['^GSPC.prev', 'GC=F.prev'], 'Today': '0001.HK', 'Params': 0.6694623768200443, 'TValues': 9.231170214054758, 'RSquared': 0.262036980623394}
# {'Prev': ['^GSPC.prev', 'GLD.prev'], 'Today': '0001.HK', 'Params': 0.6699406438432751, 'TValues': 9.243035556271424, 'RSquared': 0.26295636926374755}
# {'Prev': ['^GSPC.prev', 'GLW.prev'], 'Today': '0001.HK', 'Params': 0.6217276855596341, 'TValues': 5.48852713060046, 'RSquared': 0.2629597076330028}
# {'Prev': ['^GSPC.prev', 'GM.prev'], 'Today': '0001.HK', 'Params': 0.6291484509243204, 'TValues': 5.535234102556775, 'RSquared': 0.2626878208746152}
# {'Prev': ['^GSPC.prev', 'GOOG.prev'], 'Today': '0001.HK', 'Params': 0.6514647905994987, 'TValues': 6.4842764085320574, 'RSquared': 0.2622422209307649}
# {'Prev': ['^GSPC.prev', 'GPN.prev'], 'Today': '0001.HK', 'Params': 0.5954906856692399, 'TValues': 4.844618431760527, 'RSquared': 0.26373865001988606}
# {'Prev': ['^GSPC.prev', 'GPS.prev'], 'Today': '0001.HK', 'Params': 0.5233436603582858, 'TValues': 5.54423407804903, 'RSquared': 0.2790404424017019}
# {'Prev': ['^GSPC.prev', 'GSM.prev'], 'Today': '0001.HK', 'Params': 0.5972970546070218, 'TValues': 5.895087199182932, 'RSquared': 0.2652070920620512}
# {'Prev': ['^GSPC.prev', 'HSY.prev'], 'Today': '0001.HK', 'Params': 0.7144019611060093, 'TValues': 8.313247482026183, 'RSquared': 0.26491744227177205}
# {'Prev': ['^GSPC.prev', 'IAG.prev'], 'Today': '0001.HK', 'Params': 0.6552344127146412, 'TValues': 8.364241960111936, 'RSquared': 0.26274148335094083}
# {'Prev': ['^GSPC.prev', 'IBM.prev'], 'Today': '0001.HK', 'Params': 0.762460850038637, 'TValues': 6.535823014462684, 'RSquared': 0.26519836031369637}
# {'Prev': ['^GSPC.prev', 'IMAX.prev'], 'Today': '0001.HK', 'Params': 0.7176354734556134, 'TValues': 7.514225817835828, 'RSquared': 0.26387262103999287}
# {'Prev': ['^GSPC.prev', 'INTC.prev'], 'Today': '0001.HK', 'Params': 0.7854188373554969, 'TValues': 7.47406485299077, 'RSquared': 0.2690549002109166}
# {'Prev': ['^GSPC.prev', 'IRBT.prev'], 'Today': '0001.HK', 'Params': 0.5873319818922336, 'TValues': 6.04768466062449, 'RSquared': 0.2669340345807305}
# {'Prev': ['^GSPC.prev', 'JNJ.prev'], 'Today': '0001.HK', 'Params': 0.6641018779140305, 'TValues': 5.659477777558086, 'RSquared': 0.2620465805355209}
# {'Prev': ['^GSPC.prev', 'JPM.prev'], 'Today': '0001.HK', 'Params': 0.4491434569645458, 'TValues': 3.1980983078242198, 'RSquared': 0.27216345008835496}
# {'Prev': ['^GSPC.prev', 'KGC.prev'], 'Today': '0001.HK', 'Params': 0.6607127293959668, 'TValues': 8.384922985635322, 'RSquared': 0.26228385738216764}
# {'Prev': ['^GSPC.prev', 'KRO.prev'], 'Today': '0001.HK', 'Params': 0.6726452880480656, 'TValues': 6.454868580614699, 'RSquared': 0.26204170966249474}
# {'Prev': ['^GSPC.prev', 'LCI.prev'], 'Today': '0001.HK', 'Params': 0.6245913560687342, 'TValues': 5.993428795189963, 'RSquared': 0.26313863611711685}
# {'Prev': ['^GSPC.prev', 'MA.prev'], 'Today': '0001.HK', 'Params': 0.8237610852384312, 'TValues': 7.5204064931564565, 'RSquared': 0.2726237975086123}
# {'Prev': ['^GSPC.prev', 'MCO.prev'], 'Today': '0001.HK', 'Params': 0.7059264125198186, 'TValues': 5.641117761674047, 'RSquared': 0.26242879755317783}
# {'Prev': ['^GSPC.prev', 'MFC.prev'], 'Today': '0001.HK', 'Params': 0.6116627239544254, 'TValues': 4.410327386142275, 'RSquared': 0.2627703856738457}
# {'Prev': ['^GSPC.prev', 'MKC.prev'], 'Today': '0001.HK', 'Params': 0.6057691229113858, 'TValues': 5.4426853287066645, 'RSquared': 0.2637793131151863}
# {'Prev': ['^GSPC.prev', 'MMM.prev'], 'Today': '0001.HK', 'Params': 0.6715832463028109, 'TValues': 4.270445515733753, 'RSquared': 0.26203687699055944}
# {'Prev': ['^GSPC.prev', 'MORN.prev'], 'Today': '0001.HK', 'Params': 0.6796935818158565, 'TValues': 5.634453588085075, 'RSquared': 0.26207075799929413}
# {'Prev': ['^GSPC.prev', 'MOS.prev'], 'Today': '0001.HK', 'Params': 0.43844066239017115, 'TValues': 4.366257064670159, 'RSquared': 0.29318721297411243}
# {'Prev': ['^GSPC.prev', 'MSFT.prev'], 'Today': '0001.HK', 'Params': 0.6897881412923346, 'TValues': 5.515017386555825, 'RSquared': 0.26215838793099666}
# {'Prev': ['^GSPC.prev', 'MYL.prev'], 'Today': '0001.HK', 'Params': 0.56912534301935, 'TValues': 4.250862835690683, 'RSquared': 0.2644691825282657}
# {'Prev': ['^GSPC.prev', 'NEM.prev'], 'Today': '0001.HK', 'Params': 0.6623420296086698, 'TValues': 8.425572136152693, 'RSquared': 0.2622056129808259}
# {'Prev': ['^GSPC.prev', 'NFLX.prev'], 'Today': '0001.HK', 'Params': 0.6746173131950852, 'TValues': 8.801546441953372, 'RSquared': 0.26216831676758623}
# {'Prev': ['^GSPC.prev', 'NICE.prev'], 'Today': '0001.HK', 'Params': 0.7998762965062176, 'TValues': 6.64585599492325, 'RSquared': 0.2676363396377953}
# {'Prev': ['^GSPC.prev', 'NKE.prev'], 'Today': '0001.HK', 'Params': 0.8276434472985448, 'TValues': 8.185538246033166, 'RSquared': 0.2769039134106289}
# {'Prev': ['^GSPC.prev', 'NOC.prev'], 'Today': '0001.HK', 'Params': 0.8056965098425473, 'TValues': 6.5655780770917245, 'RSquared': 0.26778954314390546}
# {'Prev': ['^GSPC.prev', 'OMC.prev'], 'Today': '0001.HK', 'Params': 0.5456165404799016, 'TValues': 3.682732003852434, 'RSquared': 0.26484794568931835}
# {'Prev': ['^GSPC.prev', 'PST.prev'], 'Today': '0001.HK', 'Params': 0.6605537748752077, 'TValues': 6.777562944399633, 'RSquared': 0.26209381178709934}
# {'Prev': ['^GSPC.prev', 'QCOM.prev'], 'Today': '0001.HK', 'Params': 0.777800103609702, 'TValues': 6.197808633731528, 'RSquared': 0.2654522698039432}
# {'Prev': ['^GSPC.prev', 'SCHL.prev'], 'Today': '0001.HK', 'Params': 0.5977337026405698, 'TValues': 5.872504396359615, 'RSquared': 0.26511202434219994}
# {'Prev': ['^GSPC.prev', 'SI=F.prev'], 'Today': '0001.HK', 'Params': 0.6642529488153999, 'TValues': 9.019458982059225, 'RSquared': 0.2625335098497734}
# {'Prev': ['^GSPC.prev', 'SKF.prev'], 'Today': '0001.HK', 'Params': 0.5956337902897311, 'TValues': 2.576182786551691, 'RSquared': 0.2623837880697574}
# {'Prev': ['^GSPC.prev', 'SNPS.prev'], 'Today': '0001.HK', 'Params': 0.7732062334344567, 'TValues': 6.449749091130055, 'RSquared': 0.2656395669497248}
# {'Prev': ['^GSPC.prev', 'SSYS.prev'], 'Today': '0001.HK', 'Params': 0.7087412876361332, 'TValues': 7.338828457612771, 'RSquared': 0.2631979213094259}
# {'Prev': ['^GSPC.prev', 'STX.prev'], 'Today': '0001.HK', 'Params': 0.5984635334643651, 'TValues': 6.861622907772959, 'RSquared': 0.26845648957100643}
# {'Prev': ['^GSPC.prev', 'SWKS.prev'], 'Today': '0001.HK', 'Params': 0.6040059740497814, 'TValues': 6.6245431496760645, 'RSquared': 0.26628395046036557}
# {'Prev': ['^GSPC.prev', 'SYK.prev'], 'Today': '0001.HK', 'Params': 0.6004157633377931, 'TValues': 5.01694340571177, 'RSquared': 0.26364830739811873}
# {'Prev': ['^GSPC.prev', 'TBT.prev'], 'Today': '0001.HK', 'Params': 0.6341234104872315, 'TValues': 6.07383464014875, 'RSquared': 0.2627160051482077}
# {'Prev': ['^GSPC.prev', 'TCOM.prev'], 'Today': '0001.HK', 'Params': 0.5344480463457788, 'TValues': 6.097470135360123, 'RSquared': 0.2831887513035237}
# {'Prev': ['^GSPC.prev', 'TDC.prev'], 'Today': '0001.HK', 'Params': 0.7230745254080608, 'TValues': 6.554210959637426, 'RSquared': 0.2633106422160236}
# {'Prev': ['^GSPC.prev', 'TEVA.prev'], 'Today': '0001.HK', 'Params': 0.7534827103399042, 'TValues': 7.890577694871565, 'RSquared': 0.267561173349498}
# {'Prev': ['^GSPC.prev', 'TGT.prev'], 'Today': '0001.HK', 'Params': 0.6866146443367752, 'TValues': 7.49556854754523, 'RSquared': 0.26232448364977945}
# {'Prev': ['^GSPC.prev', 'TROX.prev'], 'Today': '0001.HK', 'Params': 0.6540544109230281, 'TValues': 8.48142588760339, 'RSquared': 0.26308578742396094}
# {'Prev': ['^GSPC.prev', 'TSLA.prev'], 'Today': '0001.HK', 'Params': 0.6421489598076879, 'TValues': 7.347108770414888, 'RSquared': 0.26299656097436364}
# {'Prev': ['^GSPC.prev', 'TSM.prev'], 'Today': '0001.HK', 'Params': 0.7992207280282912, 'TValues': 7.5385711612892745, 'RSquared': 0.27050720877668033}
# {'Prev': ['^GSPC.prev', 'TWM.prev'], 'Today': '0001.HK', 'Params': 0.3571812355238361, 'TValues': 1.4796429420331998, 'RSquared': 0.26764548270965716}
# {'Prev': ['^GSPC.prev', 'UMC.prev'], 'Today': '0001.HK', 'Params': 0.6673959913725135, 'TValues': 7.014024787609633, 'RSquared': 0.2620396548203423}
# {'Prev': ['^GSPC.prev', 'V.prev'], 'Today': '0001.HK', 'Params': 0.7392285186993701, 'TValues': 7.263929196772172, 'RSquared': 0.26494827117151276}
# {'Prev': ['^GSPC.prev', 'VECO.prev'], 'Today': '0001.HK', 'Params': 0.611212754611185, 'TValues': 6.633675964345519, 'RSquared': 0.2652303547844145}
# {'Prev': ['^GSPC.prev', 'VFC.prev'], 'Today': '0001.HK', 'Params': 0.6640198408362921, 'TValues': 6.631660945831629, 'RSquared': 0.2620553278739173}
# {'Prev': ['^GSPC.prev', 'VRNT.prev'], 'Today': '0001.HK', 'Params': 0.7118022422757093, 'TValues': 5.9335583610356695, 'RSquared': 0.26263882921431436}
# {'Prev': ['^GSPC.prev', 'WDC.prev'], 'Today': '0001.HK', 'Params': 0.5881632842661348, 'TValues': 6.484713742043684, 'RSquared': 0.2687173785290129}
# {'Prev': ['^GSPC.prev', 'WFC.prev'], 'Today': '0001.HK', 'Params': 0.5260920964141833, 'TValues': 3.767831228898297, 'RSquared': 0.26643994024611484}
# {'Prev': ['^GSPC.prev', 'WMT.prev'], 'Today': '0001.HK', 'Params': 0.6449657237743966, 'TValues': 6.814080058777169, 'RSquared': 0.26253437254886425}
# {'Prev': ['^GSPC.prev', '^DJI.prev'], 'Today': '0001.HK', 'Params': 1.0777573988596916, 'TValues': 2.6010429908154324, 'RSquared': 0.2651027638629637}
# {'Prev': ['^GSPC.prev', '^IXIC.prev'], 'Today': '0001.HK', 'Params': 0.724377715159878, 'TValues': 2.3978959681997853, 'RSquared': 0.262143952521008}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <listcomp>(.0)
#
# <ipython-input-20-726d3333d2b4> in get_linear_regression(pair, prevday_returns, today_returns)
#       3     column = pair['today']
#       4     X = prevday_returns[catstocks].copy()
# ----> 5     X = sm.add_constant(X)
#       6     y = today_returns[column]
#       7     model = sm.OLS(y, X).fit()
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/tools/tools.py in add_constant(data, prepend, has_constant)
#     294     if _is_using_pandas(data, None) or _is_recarray(data):
#     295         from statsmodels.tsa.tsatools import add_trend
# --> 296         return add_trend(data, trend='c', prepend=prepend, has_constant=has_constant)
#     297
#     298     # Special case for NumPy
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py in add_trend(x, trend, prepend, has_constant)
#     115         trendarr = pd.DataFrame(trendarr, index=x.index, columns=columns)
#     116         x = [trendarr, x]
# --> 117         x = pd.concat(x[::order], 1)
#     118     else:
#     119         x = [trendarr, x]
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     426         self.copy = copy
#     427
# --> 428         self.new_axes = self._get_new_axes()
#     429
#     430     def get_result(self):
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     520                 new_axes[i] = ax
#     521
# --> 522         new_axes[self.axis] = self._get_concat_axis()
#     523         return new_axes
#     524
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     573
#     574         if self.keys is None:
# --> 575             concat_axis = _concat_indexes(indexes)
#     576         else:
#     577             concat_axis = _make_concat_multiindex(
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _concat_indexes(indexes)
#     594
#     595 def _concat_indexes(indexes):
# --> 596     return indexes[0].append(indexes[1:])
#     597
#     598
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in append(self, other)
#    4335         name = None if len(names) > 1 else self.name
#    4336
# -> 4337         return self._concat(to_concat, name)
#    4338
#    4339     def _concat(self, to_concat, name):
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in _concat(self, to_concat, name)
#    4339     def _concat(self, to_concat, name):
#    4340
# -> 4341         typs = _concat.get_dtype_kinds(to_concat)
#    4342
#    4343         if len(typs) == 1:
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/dtypes/concat.py in get_dtype_kinds(l)
#      46
#      47         dtype = arr.dtype
# ---> 48         if is_categorical_dtype(dtype):
#      49             typ = "category"
#      50         elif is_sparse(arr):
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     706     if arr_or_dtype is None:
#     707         return False
# --> 708     return CategoricalDtype.is_dtype(arr_or_dtype)
#     709
#     710
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     254         dtype = getattr(dtype, "dtype", dtype)
#     255
# --> 256         if isinstance(dtype, (ABCSeries, ABCIndexClass, ABCDataFrame, np.dtype)):
#     257             # https://github.com/pandas-dev/pandas/issues/22960
#     258             # avoid passing data to `construct_from_string`. This could
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, "_typ") in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Parrallel processing

# %%
# %%time
cpu = cpu_count()
print('cpu count = {}'.format(cpu))
executor = Parallel(n_jobs=cpu, backend='multiprocessing')
tasks = (delayed(get_linear_regression)(pair, prevday_returns, today_returns) for pair in pair_list)
results = executor(tasks)
result_df = pd.DataFrame(results)
result_df

# %%
result_df.to_csv('../data/us_hk/us_hk_2indp_var_10yr_regression_pair.csv')

# %% [markdown]
# ### Read Regression Result

# %%
result2_df = pd.read_csv('../data/us_hk/us_hk_2indp_var_10yr_regression_pair.csv', index_col=0)

# %%
sorted2_df = result2_df.sort_values(by='RSquared', ascending=False)
sorted2_df.head(10)

# %%
result_df = pd.read_csv('../data/us_hk/us_hk_clean_10yr_stock_close.csv', index_col=0)
sorted_df = result_df.sort_values(by='RSquared', ascending=False)
sorted_df.head(10)

# %% [markdown]
# ### Upload to AWS S3

# %%
s3_bucket = 'slack-trading'
local_path = '../data/us_hk'
tools.upload_data_to_s3(s3_bucket, local_path)

# %% [markdown]
# ### Verify Linear regression

# %% [markdown]
#     catstock = pair['prev']
#     column = pair['today']
#     X = prevday_returns[[catstock]].copy()
#     X = sm.add_constant(X)
#     y = today_returns[[column]]
#     model = sm.OLS(y, X).fit()
#     data = {
#         'Prev' : catstock,
#         'Today' : column,
#         'Params' : model.params.iloc[1],
#         'TValues' : abs(model.tvalues.iloc[1]),
#         'RSquared' : model.rsquared
#     }

# %%
stock1 = ['0266.HK.prev', '0916.HK.prev']
stock2 = '0952.HK'

# %%
prevday_returns[stock1]

# %%
today_returns[stock2]

# %%
X = prevday_returns[stock1].copy()
X = sm.add_constant(X)
y = today_returns[stock2]
model = sm.OLS(y, X).fit()
print('Params {:.4f} TValues {:.4f} RSquared {:.4f}'.format(model.params.iloc[1], model.tvalues.iloc[1], model.rsquared))
