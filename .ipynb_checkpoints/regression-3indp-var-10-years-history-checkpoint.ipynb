# %%
import pandas as pd
import numpy as np
import datetime as dt
import statsmodels.api as sm
#
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed

import tools
import importlib
importlib.reload(tools)
# Out:
# <module 'tools' from '/home/keithyamkf/jupyter-notebook/slack-trading/tools.py'>

# %% [markdown]
# ### Download data from AWS S3

# %%
s3_bucket = 'slack-trading'
local_path = '../data'
tools.download_data_from_s3(s3_bucket, local_path)

# %% [markdown]
# ### CPU Count

# %%
cpu_count()
# Out:
# 4

# %% [markdown]
# ### Begin

# %%
# dataset = pd.read_csv('../data/all_stock_close.csv')
dataset = pd.read_csv('../data/clean_10yr_stock_close.csv')
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset.set_index('Date', drop=True, inplace=True)
dataset.head(3)
# Out:
#               0001.HK    0002.HK   0003.HK   0004.HK    0005.HK    0006.HK  \
# Date
# 2011-01-05  61.286934  42.431778  5.844519  8.506300  51.181801  27.308163
# 2011-01-06  62.620289  42.630985  5.762295  8.540971  51.461823  27.253111
# 2011-01-07  62.620289  42.630985  5.762295  8.540971  51.461823  27.253111
#
#             0007.HK   0008.HK    0010.HK    0011.HK  ...   3918.HK    3933.HK  \
# Date                                                 ...
# 2011-01-05     0.72  1.894841  41.338200  85.341171  ...  1.048637  13.528478
# 2011-01-06     0.73  1.922302  41.613262  85.276558  ...  1.109961  13.077461
# 2011-01-07     0.73  1.922302  41.613262  85.276558  ...  1.109961  13.077461
#
#               3968.HK   3988.HK  3989.HK   3993.HK   3998.HK   3999.HK  \
# Date
# 2011-01-05  14.051094  2.338585  0.43869  1.197547  2.198230  1.417399
# 2011-01-06  14.051094  2.344221  0.43869  1.177006  2.151601  1.408255
# 2011-01-07  14.051094  2.344221  0.43869  1.177006  2.151601  1.408255
#
#              6823.HK          ^HSI
# Date
# 2011-01-05  0.266144  23757.820312
# 2011-01-06  0.268354  23786.300781
# 2011-01-07  0.286030  23686.630859
#
# [3 rows x 712 columns]

# %%
train_start = '2011-01-01'
train_end = '2011-12-31'
dataset = dataset[train_start:train_end]

# %%
prevday_returns = np.log(dataset.shift(1)/dataset.shift(2))
today_returns = np.log(dataset/dataset.shift(1))
#
stocks_prev = prevday_returns.columns.to_list()
stocks_today = today_returns.columns.to_list()
#
new_col = ['{}.prev'.format(c) for c in stocks_prev]
prevday_returns.columns = new_col
#
comb_df = pd.concat([prevday_returns, today_returns], axis=1)

# %% [markdown]
# ### Fina the NaN in comb_df

# %%
comb_df.dropna(axis=0, how='any', inplace=True)

# %%
comb_df.tail(3)
# Out:
#             0001.HK.prev  0002.HK.prev  0003.HK.prev  0004.HK.prev  \
# Date
# 2011-12-28      0.012451      0.002274      0.007808      0.011281
# 2011-12-29      0.004829     -0.007599     -0.001112     -0.025573
# 2011-12-30     -0.009142     -0.000763     -0.006697     -0.004321
#
#             0005.HK.prev  0006.HK.prev  0007.HK.prev  0008.HK.prev  \
# Date
# 2011-12-28      0.014316      0.003512     -0.029853      0.054347
# 2011-12-29     -0.010084      0.006987     -0.015268     -0.003839
# 2011-12-30     -0.013606     -0.008741      0.000000      0.041437
#
#             0010.HK.prev  0011.HK.prev  ...   3918.HK   3933.HK   3968.HK  \
# Date                                    ...
# 2011-12-28      0.042260      0.007547  ...  0.005141 -0.002238 -0.017483
# 2011-12-29     -0.005764     -0.004845  ...  0.005115 -0.009009 -0.008854
# 2011-12-30      0.009206     -0.003243  ...  0.000000  0.011247 -0.002545
#
#              3988.HK   3989.HK   3993.HK   3998.HK   3999.HK   6823.HK  \
# Date
# 2011-12-28 -0.020762 -0.057175  0.000000 -0.013129 -0.007435  0.000000
# 2011-12-29  0.000000 -0.060644 -0.020495 -0.013304 -0.030305  0.000000
# 2011-12-30  0.000000  0.459543 -0.017911 -0.018019  0.015268  0.013247
#
#                 ^HSI
# Date
# 2011-12-28 -0.005949
# 2011-12-29 -0.006542
# 2011-12-30  0.001980
#
# [3 rows x 1424 columns]

# %%
comb_df.head(3)
# Out:
#             0001.HK.prev  0002.HK.prev  0003.HK.prev  0004.HK.prev  \
# Date
# 2011-01-07      0.021523      0.004684     -0.014168      0.004068
# 2011-01-10      0.000000      0.000000      0.000000      0.000000
# 2011-01-11     -0.013012     -0.003120     -0.007714     -0.014720
#
#             0005.HK.prev  0006.HK.prev  0007.HK.prev  0008.HK.prev  \
# Date
# 2011-01-07      0.005456     -0.002018      0.013793      0.014388
# 2011-01-10      0.000000      0.000000      0.000000      0.000000
# 2011-01-11     -0.012166     -0.007096      0.000000      0.019803
#
#             0010.HK.prev  0011.HK.prev  ...   3918.HK   3933.HK   3968.HK  \
# Date                                    ...
# 2011-01-07      0.006632     -0.000757  ...  0.000000  0.000000  0.000000
# 2011-01-10      0.000000      0.000000  ... -0.022347 -0.032346 -0.023367
# 2011-01-11     -0.012352     -0.008368  ... -0.011364 -0.011019  0.005016
#
#              3988.HK   3989.HK   3993.HK   3998.HK   3999.HK   6823.HK  \
# Date
# 2011-01-07  0.000000  0.000000  0.000000  0.000000  0.000000  0.063791
# 2011-01-10 -0.007238 -0.029847 -0.050939  0.015361 -0.013072 -0.044529
# 2011-01-11  0.007238 -0.015264  0.015419 -0.006116  0.013072  0.044335
#
#                 ^HSI
# Date
# 2011-01-07 -0.004199
# 2011-01-10 -0.006751
# 2011-01-11  0.009858
#
# [3 rows x 1424 columns]

# %%
prevday_returns = comb_df[new_col]
today_returns = comb_df[stocks_today]

# %% [markdown]
# ### Load the regression result to identify the 1st independent variable

# %%
result_df = pd.read_csv('../data/2indp_var_10yr_regression_pair.csv', index_col=0)
# result_df = pd.read_csv('../data/10yr_regression_pair.csv', index_col=0)
sorted_df = result_df.sort_values(by='RSquared', ascending=False)
sorted_df.head(10)
# Out:
#                                     Prev    Today    Params    TValues  \
# 309269  ['0266.HK.prev', '0916.HK.prev']  0952.HK  2.615029  12.118144
# 309069  ['0266.HK.prev', '0406.HK.prev']  0952.HK  2.524455  11.461528
# 309186  ['0266.HK.prev', '0701.HK.prev']  0952.HK  2.666816  12.304459
# 309467  ['0266.HK.prev', '2302.HK.prev']  0952.HK  2.636831  12.154519
# 309226  ['0266.HK.prev', '0823.HK.prev']  0952.HK  2.637518  12.144296
# 309337  ['0266.HK.prev', '1104.HK.prev']  0952.HK  2.596040  11.906590
# 309329  ['0266.HK.prev', '1085.HK.prev']  0952.HK  2.519347  11.337292
# 309033  ['0266.HK.prev', '0335.HK.prev']  0952.HK  2.648093  12.178767
# 308971  ['0266.HK.prev', '0219.HK.prev']  0952.HK  2.622200  12.040138
# 309110  ['0266.HK.prev', '0529.HK.prev']  0952.HK  2.659302  12.217396
#
#         RSquared
# 309269  0.406636
# 309069  0.401171
# 309186  0.400541
# 309467  0.399246
# 309226  0.397909
# 309337  0.397453
# 309329  0.396829
# 309033  0.396276
# 308971  0.395618
# 309110  0.395152

# %%
sorted_df[sorted_df['RSquared'].isna()]
# Out:
#                                     Prev    Today  Params  TValues  RSquared
# 282580  ['0001.HK.prev', '0002.HK.prev']  0865.HK     0.0      NaN       NaN
# 282581  ['0001.HK.prev', '0003.HK.prev']  0865.HK     0.0      NaN       NaN
# 282582  ['0001.HK.prev', '0004.HK.prev']  0865.HK     0.0      NaN       NaN
# 282583  ['0001.HK.prev', '0005.HK.prev']  0865.HK     0.0      NaN       NaN
# 282584  ['0001.HK.prev', '0006.HK.prev']  0865.HK     0.0      NaN       NaN
# ...                                  ...      ...     ...      ...       ...
# 363515  ['0001.HK.prev', '3993.HK.prev']  1159.HK     0.0      NaN       NaN
# 363516  ['0001.HK.prev', '3998.HK.prev']  1159.HK     0.0      NaN       NaN
# 363517  ['0001.HK.prev', '3999.HK.prev']  1159.HK     0.0      NaN       NaN
# 363518  ['0001.HK.prev', '6823.HK.prev']  1159.HK     0.0      NaN       NaN
# 363519     ['0001.HK.prev', '^HSI.prev']  1159.HK     0.0      NaN       NaN
#
# [2130 rows x 5 columns]

# %%
sorted_df.fillna(0, inplace=True)

# %% [markdown]
# ##### Find the row grouped by 'Today' with max RSquared within each group

# %%
best_prev_sofar_df = sorted_df.loc[sorted_df.groupby('Today')['RSquared'].idxmax()]
best_prev_sofar_df
# Out:
#                                     Prev    Today    Params   TValues  \
# 658     ['0910.HK.prev', '2868.HK.prev']  0001.HK -0.089022  3.920806
# 1288    ['0868.HK.prev', '1813.HK.prev']  0002.HK -0.101702  5.982480
# 1938    ['0868.HK.prev', '1185.HK.prev']  0003.HK -0.095374  4.656453
# 2343    ['1385.HK.prev', '0391.HK.prev']  0004.HK  0.173386  3.479817
# 3217    ['0910.HK.prev', '0825.HK.prev']  0005.HK -0.088839  4.199579
# ...                                  ...      ...       ...       ...
# 502387  ['0880.HK.prev', '0910.HK.prev']  3993.HK  0.269624  5.399720
# 503325  ['1966.HK.prev', '2389.HK.prev']  3998.HK  0.426845  3.226174
# 504008  ['1881.HK.prev', '2302.HK.prev']  3999.HK  0.315344  3.829024
# 504325  ['0237.HK.prev', '0420.HK.prev']  6823.HK  4.106890  9.320299
# 505188  ['0910.HK.prev', '0825.HK.prev']     ^HSI -0.069351  3.737481
#
#         RSquared
# 658     0.087150
# 1288    0.134479
# 1938    0.095390
# 2343    0.104310
# 3217    0.109424
# ...          ...
# 502387  0.137351
# 503325  0.066644
# 504008  0.086494
# 504325  0.294847
# 505188  0.086238
#
# [712 rows x 5 columns]

# %%
best_prev_sofar_df[first_indp_df['Today']=='0005.HK']
# Out:
#                                   Prev    Today    Params   TValues  RSquared
# 3217  ['0910.HK.prev', '0825.HK.prev']  0005.HK -0.088839  4.199579  0.109424

# %% [markdown]
# ### Regression

# %%
def get_linear_regression(pair, prevday_returns, today_returns):
    catstocks = pair['prev']
    column = pair['today']
    X = prevday_returns[catstocks].copy()
    X = sm.add_constant(X)
    y = today_returns[column]
    model = sm.OLS(y, X).fit()
    data = {
        'Prev' : catstocks,
        'Today' : column,
        'Params' : model.params.iloc[1],
        'TValues' : abs(model.tvalues.iloc[1]),
        'RSquared' : model.rsquared
    }
    # print(data)
    return data

# %% [markdown]
# ### Generate pair list

# %%
catstocks = new_col
pair_list = []
for column in today_returns.columns:
    best_prev_str = best_prev_sofar_df.loc[best_prev_sofar_df['Today']==column, 'Prev'].values[0]
    best_prev_list = best_prev_str.replace('\'','').strip('][').split(', ') # convert list representation to list
    for catstock in catstocks:
        if (column not in catstock) and (catstock not in best_prev_list):
            data = {
                'prev' : best_prev_list + [catstock],
                'today' : column
            }
            pair_list.append(data)
#

# %% [markdown]
# ### NON-Parallel processing

# %%
# %%time
results = [get_linear_regression(pair, prevday_returns, today_returns) for pair in pair_list]
result_df = pd.DataFrame(results)
result_df
# Out:
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2542: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0002.HK.prev'], 'Today': '0001.HK', 'Params': -0.08780587648748568, 'TValues': 3.8297635522749895, 'RSquared': 0.08783052619217402}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0003.HK.prev'], 'Today': '0001.HK', 'Params': -0.0865954753990074, 'TValues': 3.7857241983321726, 'RSquared': 0.09024571273213877}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0004.HK.prev'], 'Today': '0001.HK', 'Params': -0.08623272478598418, 'TValues': 3.715044812107554, 'RSquared': 0.08851732989199201}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0005.HK.prev'], 'Today': '0001.HK', 'Params': -0.08372016273776689, 'TValues': 3.659266557033044, 'RSquared': 0.09672383217100877}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0006.HK.prev'], 'Today': '0001.HK', 'Params': -0.08853917692533667, 'TValues': 3.8924413629345036, 'RSquared': 0.08868430245333381}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0007.HK.prev'], 'Today': '0001.HK', 'Params': -0.08680727464020775, 'TValues': 3.8080383700464275, 'RSquared': 0.09143207220886462}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0008.HK.prev'], 'Today': '0001.HK', 'Params': -0.0868153909204755, 'TValues': 3.737214960214285, 'RSquared': 0.08798533560429145}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0010.HK.prev'], 'Today': '0001.HK', 'Params': -0.08649896159760267, 'TValues': 3.7919138488599065, 'RSquared': 0.0917609324642148}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0011.HK.prev'], 'Today': '0001.HK', 'Params': -0.08518337546624924, 'TValues': 3.7125646933500818, 'RSquared': 0.09203995021327427}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0012.HK.prev'], 'Today': '0001.HK', 'Params': -0.08657414971496093, 'TValues': 3.779781220282429, 'RSquared': 0.08986541217457844}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0014.HK.prev'], 'Today': '0001.HK', 'Params': -0.08907337191031946, 'TValues': 3.910312824211531, 'RSquared': 0.08715847965104684}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '0015.HK.prev'], 'Today': '0001.HK', 'Params': -0.08410873047804622, 'TValues': 3.7250772862430734, 'RSquared': 0.10852371376027503}
# {'Prev': ['0910.HK.prev', '2868.HK.prev', '

# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0966.HK.prev'], 'Today': '0002.HK', 'Params': -0.10143954997704484, 'TValues': 5.644341493415305, 'RSquared': 0.13448703722669786}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0967.HK.prev'], 'Today': '0002.HK', 'Params': -0.0951681524124221, 'TValues': 5.298058788285705, 'RSquared': 0.13904474811714107}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0970.HK.prev'], 'Today': '0002.HK', 'Params': -0.10932509068093649, 'TValues': 5.9423182652202335, 'RSquared': 0.13872967696744387}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0973.HK.prev'], 'Today': '0002.HK', 'Params': -0.10677545031828681, 'TValues': 6.097799897817776, 'RSquared': 0.13963399370879814}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0976.HK.prev'], 'Today': '0002.HK', 'Params': -0.10084051113771311, 'TValues': 5.6256655035258385, 'RSquared': 0.13456650992150243}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0978.HK.prev'], 'Today': '0002.HK', 'Params': -0.10177975645005471, 'TValues': 5.980972410316885, 'RSquared': 0.13640263573393074}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0981.HK.prev'], 'Today': '0002.HK', 'Params': -0.10417492925583335, 'TValues': 5.940371475227962, 'RSquared': 0.13573611055163004}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0983.HK.prev'], 'Today': '0002.HK', 'Params': -0.11655453190797402, 'TValues': 6.434388435178124, 'RSquared': 0.15243698933985872}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0984.HK.prev'], 'Today': '0002.HK', 'Params': -0.1013948325875838, 'TValues': 5.96873266207447, 'RSquared': 0.13957110904403336}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0985.HK.prev'], 'Today': '0002.HK', 'Params': -0.10394102964646781, 'TValues': 5.875076466538747, 'RSquared': 0.13527272089244635}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0991.HK.prev'], 'Today': '0002.HK', 'Params': -0.1003902391685568, 'TValues': 5.684362930104223, 'RSquared': 0.1347679478434881}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0992.HK.prev'], 'Today': '0002.HK', 'Params': -0.09662211657415859, 'TValues': 5.392778059881669, 'RSquared': 0.1374343892426253}
# {'Prev': ['0868.HK.prev', '1813.HK.prev', '0995.HK.prev'], 'Today': '0002.HK', 'Params': -0.09707830645954, 'TValues': 5.633577874354051, 'RSquared': 0.14265191919820808}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <listcomp>(.0)
#
# <ipython-input-31-726d3333d2b4> in get_linear_regression(pair, prevday_returns, today_returns)
#       5     X = sm.add_constant(X)
#       6     y = today_returns[column]
# ----> 7     model = sm.OLS(y, X).fit()
#       8     data = {
#       9         'Prev' : catstocks,
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         self.const_idx = None
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     471         #TODO: remove this when we handle dtype systematically
#     472         endog = np.asarray(endog)
# --> 473         exog = exog if exog is None else np.asarray(exog)
#     474         if endog.dtype == object or exog is not None and exog.dtype == object:
#     475             raise ValueError("Pandas data cast to numpy dtype of object. "
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1993
#    1994     def __array__(self, dtype=None):
# -> 1995         return com.values_from_object(self)
#    1996
#    1997     def __array_wrap__(self, result, context=None):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/generic.py in values(self)
#    5441         """
#    5442         self._consolidate_inplace()
# -> 5443         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5444
#    5445     @property
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/internals/managers.py in as_array(self, transpose, items)
#     812             mgr = self
#     813
# --> 814         if self._is_single_block and mgr.blocks[0].is_datetimetz:
#     815             # TODO(Block.get_values): Make DatetimeTZBlock.get_values
#     816             # always be object dtype. Some callers seem to want the
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/internals/managers.py in _is_single_block(self)
#     211         blk = self.blocks[0]
#     212         return blk.mgr_locs.is_slice_like and blk.mgr_locs.as_slice == slice(
# --> 213             0, len(self), 1
#     214         )
#     215
#
# /opt/miniconda3/envs/conda_env/lib/python3.7/site-packages/pandas/core/internals/managers.py in __len__(self)
#     323         self._rebuild_blknos_and_blklocs()
#     324
# --> 325     def __len__(self):
#     326         return len(self.items)
#     327
#
# KeyboardInterrupt:

# %% [markdown]
# ### Parrallel processing

# %%
# %%time
cpu = cpu_count()
print('cpu count = {}'.format(cpu))
executor = Parallel(n_jobs=cpu, backend='multiprocessing')
tasks = (delayed(get_linear_regression)(pair, prevday_returns, today_returns) for pair in pair_list)
results = executor(tasks)
result_df = pd.DataFrame(results)
result_df

# %%
result_df.to_csv('../data/3indp_var_10yr_regression_pair.csv')

# %% [markdown]
# ### Read Regression Result

# %%
result2_df = pd.read_csv('../data/3indp_var_10yr_regression_pair.csv', index_col=0)

# %%
sorted2_df = result2_df.sort_values(by='RSquared', ascending=False)
sorted2_df.head(10)

# %%
result_df = pd.read_csv('../data/2indp_var_10yr_regression_pair.csv', index_col=0)
sorted_df = result_df.sort_values(by='RSquared', ascending=False)
sorted_df.head(10)

# %% [markdown]
# ### Upload to AWS S3

# %%
s3_bucket = 'slack-trading'
local_path = '../data'
tools.upload_data_to_s3(s3_bucket, local_path)

# %% [markdown]
# ### Verify Linear regression

# %% [markdown]
#     catstock = pair['prev']
#     column = pair['today']
#     X = prevday_returns[[catstock]].copy()
#     X = sm.add_constant(X)
#     y = today_returns[[column]]
#     model = sm.OLS(y, X).fit()
#     data = {
#         'Prev' : catstock,
#         'Today' : column,
#         'Params' : model.params.iloc[1],
#         'TValues' : abs(model.tvalues.iloc[1]),
#         'RSquared' : model.rsquared
#     }

# %%
stock1 = ['0266.HK.prev', '0916.HK.prev']
stock2 = '0952.HK'

# %%
prevday_returns[stock1]

# %%
today_returns[stock2]

# %%
X = prevday_returns[stock1].copy()
X = sm.add_constant(X)
y = today_returns[stock2]
model = sm.OLS(y, X).fit()
print('Params {:.4f} TValues {:.4f} RSquared {:.4f}'.format(model.params.iloc[1], model.tvalues.iloc[1], model.rsquared))
